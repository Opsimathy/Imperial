# %% [markdown]
# # Coursework 2 - Part 1

# %% [markdown]
# # Outline
#
# - [Task 1](#task-1): Classification with a Convolutional Neural Network <a name="index-task-1"></a>
#   - [(1.1)](#task-11) <a name="index-task-11"></a>
#   - [(1.2)](#task-12) <a name="index-task-12"></a>
#   - [(1.3, BSc/3rd-year students only)](#task-13b) <a name="index-task-13b"></a>
#   - [(1.3, MSc/4th-year students only)](#task-13m) <a name="index-task-13m"></a>
# - [Task 2](#task-2): Dimensionality Reduction: PCA vs ISOMAP <a name="index-task-2"></a>
#   - [(2.1)](#task-21)
#   - [(2.2)](#task-22)
#   - [(2.3)](#task-23)

# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg
import pandas as pd
from tqdm.notebook import tqdm

# Importing losses, activation functions and layers from PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.nn import Sequential, CrossEntropyLoss, Conv2d, MaxPool2d, Flatten, Linear, ReLU, Softmax, Parameter
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn


# we define a mix of fontsizes, for different parts of a plot
SMALL_SIZE = 12
MEDIUM_SIZE = 16
BIGGER_SIZE = 20

# example of how you can use these fontsizes to set a global configuration for matplotlib;
# you should assign them based on the specific appearance of the figures you are producing
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)   # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# First, I import the data: `star_images_train` and `star_images_test` contain. respectively, 648 and 32 images, each specified by a $32 \times 32$ array. `star_classes_train` and `star_classes_test` contain the corresponding classes of the star images.

# %%
# importing data

star_images_train = np.load('star_images_train.npy')
star_classes_train = np.load('star_classes_train.npy')
star_images_test = np.load('star_images_test.npy')
star_classes_test = np.load('star_classes_test.npy')

classes = ['05V', 'A0V', 'F5V', 'M5V']
value_to_type = {0: 'O5V', 1: 'A0V', 2: 'F5V', 3: 'M5V'}  # mapping of class value to star image type
N = star_images_train.shape[0]  # Number of samples
# Out:
# Mounted at /content/drive

# %% [markdown]
# <a name="task-1"></a>
#
# # (1) Task 1: Classification with a Convolutional Neural Network [(index)](#index-task-1)

# %% [markdown]
# <a name="task-11"></a>
#
# ## (1.1) [(index)](#index-task-11)

# %% [markdown]
# I start by splitting and plotting the data.

# %%
def dataset_split(train_x, train_y, val_size):
    """
    Splits the dataset into training and validation sets.

    Parameters:
    train_x: Dataset input arrays
    train_y: Dataset output value or class
    val_size: Proportion of the total dataset that corresponds to the validation set

    Returns:
    x_train: Training set inputs
    y_train: Training set outputs
    x_val: Validation set inputs
    y_val: Validation set outputs

    """

    indices_train = np.arange(len(train_x))
    np.random.seed(0)
    indices_val = np.random.choice(indices_train, int(len(train_x)*val_size), replace=False) # Key to replace=False, otherwise one gets repeated values!
    indices_train = [idx for idx in indices_train if idx not in indices_val]

    return train_x[indices_train], train_y[indices_train], train_x[indices_val], train_y[indices_val]

val_size = 0.25
x_train, y_train, x_val, y_val = dataset_split(star_images_train, star_classes_train, val_size)
x_test, y_test = star_images_test, star_classes_test

# %%
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (486, 32, 32)
# (486,)
# (162, 32, 32)
# (162,)
# (32, 32, 32)
# (32,)

# %% [markdown]
# The input data consists of $32 \times 32$ images. There are 648 training/validation examples and 32 test examples.

# %%
# Plot a randomly selected example from each class
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

for l, label in enumerate(range(len(classes))):
    inx = np.where(y_train == label)[0]
    i = np.random.choice(inx)
    x_example = x_train[i]
    row = l // 2
    col = l % 2
    im = ax[row, col].imshow(x_example, cmap='gist_stern')
    ax[row, col].set_title(classes[l])
    cbar = fig.colorbar(im, ax=ax[row, col], fraction=0.046, pad=0.04)

# %% [markdown]
# I build the CNN model in PyTorch to train on the star dataset:
#
# * A `Conv2d` layer with 4 filters, kernel shape of (5, 5) and a `ReLU` activation function
#   * L2 weight regularisation with a coefficient to be found through cross-validation in 1.2.
# * A `MaxPoo2d` layer with a pooling window size of (2,2) and a stride of 2
# * Another `Conv2d` layer with 8 filters, kernel shape of (5, 5) and a `ReLU` activation function
#   * L2 weight regularisation with a coefficient to be found through cross-validation in 1.2.
# * A `Flatten` layer
# * A `Linear` layer and a `Softmax` activation
#
# The function below builds and compiles this model, using an `Adam` optimiser and a `CrossEntropyLoss` criterion.

# %%
class StarCNN(nn.Module):
    def __init__(self, n_filters, k, pool_size, stride_pool, l_in_linear, classes):
        super(StarCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, n_filters, kernel_size=(k,k))
        self.conv2 = nn.Conv2d(n_filters, 2*n_filters, kernel_size=(k,k))
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=(pool_size, pool_size), stride=stride_pool)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(l_in_linear, len(classes))
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.flatten(x)
        x = self.fc(x)
        x = self.softmax(x)

        return x

# %%
def get_model(x_train, n_filters, k, pool_size, stride_pool, classes):
    """
    CNN model in PyTorch:
    - Layers are Conv1d(+ReLU), MaxPool1d, Flatten and Linear(+Softmax).
    - It features an Adam optimiser and CrossEntropyLoss criterion.
    - Conv1d and Linear layers have regularised weights according to l2_reg.

    Parameters:
    x_train: Training data
    n_filters: Number of filters to be used in the convolutional layer
    k: Kernel size in the convolutional layer
    pool_size: MaxPool1d window size
    stride_pool: Stride of the MaxPool1d sliding window
    classes: List containing the output classes

    Returns:
    Model, criterion and optimiser.

    """

    l_out_conv1 = x_train.shape[-1] - k + 1 # Length after Conv2d_1 (note that the stride is 1) ## <-- SOLUTION
    l_out_pool1 = (l_out_conv1 - pool_size) // stride_pool + 1 # Length after MaxPool2d_1 ## <-- SOLUTION
    l_out_conv2 = l_out_pool1 - k + 1 # Length after Conv2d_2 ## <-- SOLUTION
    l_in_linear = 2 * n_filters * l_out_conv2 ** 2 # Size before Linear layer ## <-- SOLUTION

    model = StarCNN(n_filters, k, pool_size, stride_pool, l_in_linear, classes)

    criterion = CrossEntropyLoss() ## <-- SOLUTION
    optimiser = torch.optim.Adam(model.parameters()) ## <-- SOLUTION

    return model, criterion, optimiser

# %%
# Run your function to get the model and print it

n_filters = 4
k = 5
pool_size = 2
stride_pool = 2

model, criterion, optimiser = get_model(x_train, n_filters, k, pool_size, stride_pool, classes) ## <-- SOLUTION
print(model)
# Out:
# StarCNN(
#   (conv1): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(4, 8, kernel_size=(5, 5), stride=(1, 1))
#   (relu): ReLU()
#   (maxpool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc): Linear(in_features=800, out_features=4, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# Now I am ready to train the model. The `training_loop` function should run the training for `max_num_epochs` of 200 and `batch_size` of 128, featuring early stopping to monitor the validation accuracy. We set the `max_patience` parameter to 150 epochs. The function should return the training and validation history, which includes the loss and accuracy.

# %%
def create_dataloaders(x_train, y_train, x_val, y_val, batch_size=128):
    """
    Converts numpy arrays into PyTorch DataLoader objects for training and validation.

    Parameters:
    x_train: Training set images
    y_train: Training set labels
    x_val: Validation set images
    y_val: Validation set labels
    batch_size: Batch size for DataLoader

    Returns:
    train_loader: DataLoader for training data
    val_loader: DataLoader for validation data

    """
    x_train_tensor = torch.tensor(x_train.reshape(x_train.shape[0], 1, x_train.shape[1], x_train.shape[2]), dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train)
    x_val_tensor = torch.tensor(x_val.reshape(x_val.shape[0], 1, x_val.shape[1], x_val.shape[2]), dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val)

    train_dataset = TensorDataset(x_train_tensor, y_train_tensor.squeeze())
    val_dataset = TensorDataset(x_val_tensor, y_val_tensor.squeeze())
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader

train_loader, val_loader = create_dataloaders(x_train, y_train, x_val, y_val, batch_size=128)

# %%
class EarlyStopping:
    """
    EarlyStopping class.

    Attributes:
    max_patience: Amount of epochs with no improvement after which training is stopped.
    patience: Stores the number of epochs with no improvement.
    best_valid_loss: Stores the current value of the best (minimum) validation loss.
    early_stop: True if training needs to be stopped due to the early stopping condition being met.

    Methods:
    step(val_loss):
        Checks current state after an epoch and updates best_loss, patience and early_stop accordingly.
    """

    def __init__(self, max_patience=150):
        self.max_patience = max_patience
        self.patience = 0
        self.best_valid_loss = float('inf') ## <-- SOLUTION
        self.early_stop = False

    def step(self, val_loss):
        if val_loss < self.best_valid_loss:  ## <-- SOLUTION
            self.best_valid_loss = val_loss  ## <-- SOLUTION
            self.patience = 0  ## <-- SOLUTION
        else:
            self.patience += 1
            if self.patience >= self.max_patience:
                self.early_stop = True

# %%
def training_loop(model, train_loader, val_loader, criterion, optimiser, max_num_epochs=200, max_patience=150, reg_strength=0):
    """
    Training loop with early stopping to monitor the validation accuracy.

    Parameters:
    model: Instance of StarCNN
    train_loader: Training DataLoader
    val_loader: Validation DataLoader
    criterion: Loss function used for training
    optimiser: Optimiser used for training
    max_num_epochs: Maximum number of epochs
    max_patience: max_patience attribute of the EarlyStopping class
    reg_strength: the regularisation parameter

    Returns:
    History.

    """

    history = {'training_loss': [], 'validation_loss': [], 'training_accuracy': [], 'validation_accuracy': []}
    early_stopping = EarlyStopping(max_patience=max_patience)

    for epoch in range(max_num_epochs):

        tr_loss = 0.0
        tr_correct = 0
        val_loss = 0.0
        val_correct = 0

        # Training
        model.train()
        for inputs, labels in train_loader:
            optimiser.zero_grad() # Setting gradients to zero
            outputs = model(inputs)
            loss = criterion(outputs, labels) ## <-- SOLUTION
            #if reg_strength:
            #    loss += reg_strength * (torch.norm(model.conv1.weight, p=2) ** 2 + torch.norm(model.conv2.weight, p=2) ** 2)
            tr_loss += loss.item()
            tr_correct += (outputs.argmax(dim=1) == labels).sum().item() ## <-- SOLUTION
            loss.backward() # Computes gradients of the loss
            optimiser.step() # Optimisation step (parameters are updated)

        history['training_loss'].append(tr_loss/len(train_loader))
        history['training_accuracy'].append(100*tr_correct/len(train_loader.dataset))

        # Validation
        model.eval()
        with torch.no_grad():
            for inputs_v, labels_v in val_loader:
                outputs_v = model(inputs_v)
                loss_v = criterion(outputs_v, labels_v)  ## <-- SOLUTION
                val_loss += loss_v.item()
                if labels_v.size(0):
                    val_correct += (outputs_v.argmax(dim=1) == labels_v).sum().item() ## <-- SOLUTION

        history['validation_loss'].append(val_loss/len(val_loader))
        history['validation_accuracy'].append(100*val_correct/len(val_loader.dataset))

        # Print progress every 50 epochs
        if (epoch + 1) % 50 == 0 or epoch == 0:
            print(f'Epoch {epoch + 1}/{max_num_epochs}, Training loss: {tr_loss/len(train_loader)}, Training accuracy: {100*tr_correct/len(train_loader.dataset)}%, Validation loss: {val_loss/len(val_loader)}, Validation accuracy: {100*val_correct/len(val_loader.dataset)}%')

        # Check for early stopping
        early_stopping.step(val_loss / len(val_loader))
        if early_stopping.early_stop:
            print("Early stopping acting.")  ## <-- SOLUTION
            break  ## <-- SOLUTION

    return history

# %% [markdown]
# ---

# %%
# Calling the training loop
max_num_epochs = 2000
max_patience = 150

model, criterion, optimiser = get_model(x_train, n_filters, k, pool_size, stride_pool, classes) ## <-- SOLUTION
history = training_loop(model, train_loader, val_loader, criterion, optimiser, max_num_epochs, max_patience)
# Out:
# Epoch 1/2000, Training loss: 1.3873761296272278, Training accuracy: 23.662551440329217%, Validation loss: 1.3873851895332336, Validation accuracy: 25.308641975308642%
# Epoch 50/2000, Training loss: 1.3849241137504578, Training accuracy: 26.954732510288064%, Validation loss: 1.3877984285354614, Validation accuracy: 25.308641975308642%
# Epoch 100/2000, Training loss: 1.381636142730713, Training accuracy: 26.954732510288064%, Validation loss: 1.3845093846321106, Validation accuracy: 25.308641975308642%
# Epoch 150/2000, Training loss: 1.3414779901504517, Training accuracy: 42.38683127572016%, Validation loss: 1.3380702137947083, Validation accuracy: 40.74074074074074%
# Epoch 200/2000, Training loss: 1.2551804780960083, Training accuracy: 51.02880658436214%, Validation loss: 1.2581475377082825, Validation accuracy: 48.148148148148145%
# Epoch 250/2000, Training loss: 1.2088124752044678, Training accuracy: 51.851851851851855%, Validation loss: 1.2196643352508545, Validation accuracy: 49.382716049382715%
# Epoch 300/2000, Training loss: 1.1799366474151611, Training accuracy: 60.49382716049383%, Validation loss: 1.195751428604126, Validation accuracy: 52.46913580246913%
# Epoch 350/2000, Training loss: 1.1624447703361511, Training accuracy: 60.90534979423868%, Validation loss: 1.1841711401939392, Validation accuracy: 53.08641975308642%
# Epoch 400/2000, Training loss: 1.147440254688263, Training accuracy: 60.288065843621396%, Validation loss: 1.1708622574806213, Validation accuracy: 58.02469135802469%
# Epoch 450/2000, Training loss: 1.1322691142559052, Training accuracy: 63.37448559670782%, Validation loss: 1.1561074256896973, Validation accuracy: 59.876543209876544%
# Epoch 500/2000, Training loss: 1.118536114692688, Training accuracy: 65.02057613168725%, Validation loss: 1.146970272064209, Validation accuracy: 60.49382716049383%
# Epoch 550/2000, Training loss: 1.0999524891376495, Training accuracy: 67.6954732510288%, Validation loss: 1.131887137889862, Validation accuracy: 62.34567901234568%
# Epoch 600/2000, Training loss: 1.0882445275783539, Training accuracy: 69.34156378600824%, Validation loss: 1.119188368320465, Validation accuracy: 62.34567901234568%
# Epoch 650/2000, Training loss: 1.0753058195114136, Training accuracy: 70.57613168724279%, Validation loss: 1.1028028726577759, Validation accuracy: 67.90123456790124%
# Epoch 700/2000, Training loss: 1.058576077222824, Training accuracy: 72.01646090534979%, Validation loss: 1.0808488130569458, Validation accuracy: 67.90123456790124%
# Epoch 750/2000, Training loss: 1.0448967516422272, Training accuracy: 73.66255144032922%, Validation loss: 1.0676944255828857, Validation accuracy: 68.51851851851852%
# Epoch 800/2000, Training loss: 1.0338378846645355, Training accuracy: 74.89711934156378%, Validation loss: 1.056430995464325, Validation accuracy: 69.1358024691358%
# Epoch 850/2000, Training loss: 1.0280132591724396, Training accuracy: 75.7201646090535%, Validation loss: 1.045757234096527, Validation accuracy: 71.60493827160494%
# Epoch 900/2000, Training loss: 1.016481950879097, Training accuracy: 76.74897119341564%, Validation loss: 1.0360374450683594, Validation accuracy: 71.60493827160494%
# Epoch 950/2000, Training loss: 1.0133454501628876, Training accuracy: 77.1604938271605%, Validation loss: 1.0301894545555115, Validation accuracy: 72.8395061728395%
# Epoch 1000/2000, Training loss: 1.0025967210531235, Training accuracy: 78.18930041152264%, Validation loss: 1.0212489366531372, Validation accuracy: 73.45679012345678%
# Epoch 1050/2000, Training loss: 0.9980674088001251, Training accuracy: 78.80658436213992%, Validation loss: 1.0182893574237823, Validation accuracy: 72.8395061728395%
# Epoch 1100/2000, Training loss: 0.9933100193738937, Training accuracy: 79.42386831275721%, Validation loss: 1.0076375305652618, Validation accuracy: 75.30864197530865%
# Epoch 1150/2000, Training loss: 0.9886892437934875, Training accuracy: 78.39506172839506%, Validation loss: 1.0047915279865265, Validation accuracy: 75.92592592592592%
# Epoch 1200/2000, Training loss: 0.9847692847251892, Training accuracy: 79.62962962962963%, Validation loss: 0.9965537190437317, Validation accuracy: 75.30864197530865%
# Epoch 1250/2000, Training loss: 0.9796782284975052, Training accuracy: 80.04115226337449%, Validation loss: 0.9931862056255341, Validation accuracy: 75.92592592592592%
# Epoch 1300/2000, Training loss: 0.9763830155134201, Training accuracy: 80.8641975308642%, Validation loss: 0.9896031320095062, Validation accuracy: 77.1604938271605%
# Epoch 1350/2000, Training loss: 0.970877468585968, Training accuracy: 80.65843621399176%, Validation loss: 0.9808945059776306, Validation accuracy: 77.1604938271605%
# Epoch 1400/2000, Training loss: 0.9679023027420044, Training accuracy: 81.06995884773663%, Validation loss: 0.980323076248169, Validation accuracy: 77.77777777777777%
# Epoch 1450/2000, Training loss: 0.9611216634511948, Training accuracy: 81.48148148148148%, Validation loss: 0.9732924103736877, Validation accuracy: 77.1604938271605%
# Epoch 1500/2000, Training loss: 0.957842081785202, Training accuracy: 81.6872427983539%, Validation loss: 0.9663506150245667, Validation accuracy: 78.39506172839506%
# Epoch 1550/2000, Training loss: 0.9562167227268219, Training accuracy: 82.3045267489712%, Validation loss: 0.9609534740447998, Validation accuracy: 79.01234567901234%
# Epoch 1600/2000, Training loss: 0.9530830681324005, Training accuracy: 82.09876543209876%, Validation loss: 0.9591470658779144, Validation accuracy: 79.01234567901234%
# Epoch 1650/2000, Training loss: 0.9478321969509125, Training accuracy: 82.71604938271605%, Validation loss: 0.9517192542552948, Validation accuracy: 80.8641975308642%
# Epoch 1700/2000, Training loss: 0.9463804811239243, Training accuracy: 82.3045267489712%, Validation loss: 0.9485789239406586, Validation accuracy: 79.62962962962963%
# Epoch 1750/2000, Training loss: 0.9420506060123444, Training accuracy: 82.51028806584362%, Validation loss: 0.9452540278434753, Validation accuracy: 79.01234567901234%
# Epoch 1800/2000, Training loss: 0.9359620213508606, Training accuracy: 84.15637860082305%, Validation loss: 0.942110002040863, Validation accuracy: 80.8641975308642%
# Epoch 1850/2000, Training loss: 0.9328214079141617, Training accuracy: 84.36213991769547%, Validation loss: 0.9377656877040863, Validation accuracy: 81.48148148148148%
# Epoch 1900/2000, Training loss: 0.9298229217529297, Training accuracy: 84.15637860082305%, Validation loss: 0.9314336776733398, Validation accuracy: 81.48148148148148%
# Epoch 1950/2000, Training loss: 0.9249514192342758, Training accuracy: 85.18518518518519%, Validation loss: 0.9245193302631378, Validation accuracy: 83.33333333333333%
# Epoch 2000/2000, Training loss: 0.9224771112203598, Training accuracy: 85.59670781893004%, Validation loss: 0.9202585816383362, Validation accuracy: 83.33333333333333%

# %% [markdown]
# I now analyse convergence:

# %%
def plot_loss_accuracy(history):
    """
    Plots of training and validation loss and accuracy over epochs.

    Parameters:
    history: Dictionary containing 'training_loss', 'validation_loss', 'training_accuracy', and 'validation_accuracy' lists.

    """

    fig = plt.figure(figsize=(12, 5))

    fig.add_subplot(121)
    plt.plot(history['training_loss'], label='Train')
    plt.plot(history['validation_loss'], label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('Cross-entropy loss')
    plt.title('Learning curve')
    plt.legend()

    fig.add_subplot(122)
    plt.plot(history['training_accuracy'], label='Train')
    plt.plot(history['validation_accuracy'], label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('Categorical accuracy')
    plt.title('Accuracy as a function of the epoch')
    plt.legend()

    plt.show()

plot_loss_accuracy(history)

# %% [markdown]
# I can see from the plot on the left that the validation loss closely follows the trend of the training loss, suggesting that the model is generalising well rather than overfitting to the training data. As both losses appear to keep decreasing towards the end, by just looking at this plot we might decide to train further to see if they fully *plateau*.
#
# The accuracy plot also reflects this pattern: the validation accuracy remains closely aligned with the training accuracy throughout the training process. Moreover, here one can see stabilisation towards the end, indicating that the model has reached its learning capacity and achieved convergence.

# %%
def evaluate_model(model, x_test, y_test):
    """
    Computes the accuracy of the model on the test set.

    Parameters:
    model: Instance of StarCNN
    x_test: Test set inputs
    y_test: Test set outputs

    """

    x_test_tensor = torch.tensor(x_test.reshape(x_test.shape[0], 1, x_test.shape[1], x_test.shape[2]), dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test)

    model.eval()
    with torch.no_grad():
        outputs = model(x_test_tensor)
        accuracy = (outputs.argmax(dim=1) == y_test_tensor).sum().item() / len(y_test) * 100
    return accuracy

test_accuracy = evaluate_model(model, x_test, y_test)
print(f'The test accuracy is {test_accuracy}%.')
# Out:
# The test accuracy is 84.375%.

# %% [markdown]
# <a name="task-12"></a>
#
# ## (1.2) [(index)](#index-task-12)

# %% [markdown]
# Now I scan over values $0.001$, $0.01$, $0.1$, $1$, and $10$ to find the optimal regularisation strength. Note that the loss function was adapted in the training loop to penalise the weights of the convolutional layers.

# %%
reg_strength_list = [0.001, 0.01, 0.1, 1, 10]
val_acc_list = []

for reg_strength in reg_strength_list:
    print('For regularisation strength =', reg_strength)
    model, criterion, optimiser = get_model(x_train, n_filters, k, pool_size, stride_pool, classes) ## <-- SOLUTION
    history = training_loop(model, train_loader, val_loader, criterion, optimiser, max_num_epochs, max_patience, reg_strength=reg_strength)
    val_acc_list.append(history['validation_accuracy'][-1])
    print('Validation accuracy (%) =', val_acc_list[-1])

opt_reg_strength = reg_strength_list[np.argmax(val_acc_list)]
print('The optimal regularisation strength is', opt_reg_strength)
# Out:
# For regularisation strength = 0.001
# Epoch 1/2000, Training loss: 1.3864969611167908, Training accuracy: 24.48559670781893%, Validation loss: 1.3856018781661987, Validation accuracy: 25.925925925925927%
# Epoch 50/2000, Training loss: 1.3781791031360626, Training accuracy: 27.77777777777778%, Validation loss: 1.3787543177604675, Validation accuracy: 28.395061728395063%
# Epoch 100/2000, Training loss: 1.2903965711593628, Training accuracy: 45.267489711934154%, Validation loss: 1.266484260559082, Validation accuracy: 46.91358024691358%
# Epoch 150/2000, Training loss: 1.2224999964237213, Training accuracy: 48.559670781893004%, Validation loss: 1.2050364017486572, Validation accuracy: 48.76543209876543%
# Epoch 200/2000, Training loss: 1.1890761852264404, Training accuracy: 57.61316872427984%, Validation loss: 1.1812325716018677, Validation accuracy: 54.93827160493827%
# Epoch 250/2000, Training loss: 1.1668757200241089, Training accuracy: 61.111111111111114%, Validation loss: 1.168241798877716, Validation accuracy: 57.407407407407405%
# Epoch 300/2000, Training loss: 1.1505140662193298, Training accuracy: 62.34567901234568%, Validation loss: 1.1588777899742126, Validation accuracy: 58.641975308641975%
# Epoch 350/2000, Training loss: 1.1355799436569214, Training accuracy: 62.55144032921811%, Validation loss: 1.151202380657196, Validation accuracy: 58.641975308641975%
# Epoch 400/2000, Training loss: 1.1271022260189056, Training accuracy: 63.16872427983539%, Validation loss: 1.143206238746643, Validation accuracy: 56.79012345679013%
# Epoch 450/2000, Training loss: 1.1154495775699615, Training accuracy: 64.60905349794238%, Validation loss: 1.135661005973816, Validation accuracy: 58.02469135802469%
# Epoch 500/2000, Training loss: 1.1094146370887756, Training accuracy: 65.84362139917695%, Validation loss: 1.1349163055419922, Validation accuracy: 58.641975308641975%
# Epoch 550/2000, Training loss: 1.1006523370742798, Training accuracy: 66.04938271604938%, Validation loss: 1.1217056512832642, Validation accuracy: 59.876543209876544%
# Epoch 600/2000, Training loss: 1.0950577557086945, Training accuracy: 66.46090534979425%, Validation loss: 1.1153973937034607, Validation accuracy: 58.641975308641975%
# Epoch 650/2000, Training loss: 1.0879695117473602, Training accuracy: 67.28395061728395%, Validation loss: 1.109200894832611, Validation accuracy: 59.25925925925926%
# Epoch 700/2000, Training loss: 1.0807518362998962, Training accuracy: 67.28395061728395%, Validation loss: 1.1039437055587769, Validation accuracy: 58.641975308641975%
# Epoch 750/2000, Training loss: 1.0767524242401123, Training accuracy: 68.51851851851852%, Validation loss: 1.0973399877548218, Validation accuracy: 60.49382716049383%
# Epoch 800/2000, Training loss: 1.073637992143631, Training accuracy: 67.90123456790124%, Validation loss: 1.0918979048728943, Validation accuracy: 61.111111111111114%
# Epoch 850/2000, Training loss: 1.065184623003006, Training accuracy: 69.1358024691358%, Validation loss: 1.0865870118141174, Validation accuracy: 61.72839506172839%
# Epoch 900/2000, Training loss: 1.0595009922981262, Training accuracy: 68.72427983539094%, Validation loss: 1.0821072459220886, Validation accuracy: 63.58024691358025%
# Epoch 950/2000, Training loss: 1.0575672090053558, Training accuracy: 69.75308641975309%, Validation loss: 1.0789687037467957, Validation accuracy: 64.19753086419753%
# Epoch 1000/2000, Training loss: 1.0492418706417084, Training accuracy: 70.37037037037037%, Validation loss: 1.0713679194450378, Validation accuracy: 62.96296296296296%
# Epoch 1050/2000, Training loss: 1.0416539311408997, Training accuracy: 71.39917695473251%, Validation loss: 1.0664112567901611, Validation accuracy: 62.96296296296296%
# Epoch 1100/2000, Training loss: 1.0368352383375168, Training accuracy: 72.22222222222223%, Validation loss: 1.0616814494132996, Validation accuracy: 63.58024691358025%
# Epoch 1150/2000, Training loss: 1.0337582528591156, Training accuracy: 72.42798353909465%, Validation loss: 1.0555445551872253, Validation accuracy: 64.81481481481481%
# Epoch 1200/2000, Training loss: 1.0235443711280823, Training accuracy: 73.04526748971193%, Validation loss: 1.051501214504242, Validation accuracy: 63.58024691358025%
# Epoch 1250/2000, Training loss: 1.0228857696056366, Training accuracy: 74.07407407407408%, Validation loss: 1.05119389295578, Validation accuracy: 64.81481481481481%
# Epoch 1300/2000, Training loss: 1.0160228610038757, Training accuracy: 74.2798353909465%, Validation loss: 1.0398702025413513, Validation accuracy: 65.4320987654321%
# Epoch 1350/2000, Training loss: 1.0118217766284943, Training accuracy: 75.10288065843622%, Validation loss: 1.040582001209259, Validation accuracy: 67.90123456790124%
# Epoch 1400/2000, Training loss: 1.0054257214069366, Training accuracy: 75.7201646090535%, Validation loss: 1.0316894054412842, Validation accuracy: 67.28395061728395%
# Epoch 1450/2000, Training loss: 1.0043457448482513, Training accuracy: 76.74897119341564%, Validation loss: 1.0297281742095947, Validation accuracy: 67.28395061728395%
# Epoch 1500/2000, Training loss: 0.9965598583221436, Training accuracy: 77.1604938271605%, Validation loss: 1.027204990386963, Validation accuracy: 69.75308641975309%
# Epoch 1550/2000, Training loss: 0.993230864405632, Training accuracy: 77.36625514403292%, Validation loss: 1.0177627801895142, Validation accuracy: 70.98765432098766%
# Epoch 1600/2000, Training loss: 0.9851977378129959, Training accuracy: 78.39506172839506%, Validation loss: 1.0126951336860657, Validation accuracy: 72.22222222222223%
# Epoch 1650/2000, Training loss: 0.9829259961843491, Training accuracy: 80.8641975308642%, Validation loss: 1.0086643397808075, Validation accuracy: 72.22222222222223%
# Epoch 1700/2000, Training loss: 0.9787893146276474, Training accuracy: 80.8641975308642%, Validation loss: 1.0010018348693848, Validation accuracy: 74.69135802469135%
# Epoch 1750/2000, Training loss: 0.9754095375537872, Training accuracy: 79.62962962962963%, Validation loss: 0.9943926930427551, Validation accuracy: 75.30864197530865%
# Epoch 1800/2000, Training loss: 0.9662236869335175, Training accuracy: 82.09876543209876%, Validation loss: 0.994834691286087, Validation accuracy: 75.92592592592592%
# Epoch 1850/2000, Training loss: 0.9599890559911728, Training accuracy: 82.09876543209876%, Validation loss: 0.9851053059101105, Validation accuracy: 76.54320987654322%
# Epoch 1900/2000, Training loss: 0.9563259333372116, Training accuracy: 82.3045267489712%, Validation loss: 0.9808571934700012, Validation accuracy: 77.1604938271605%
# Epoch 1950/2000, Training loss: 0.9489531368017197, Training accuracy: 84.36213991769547%, Validation loss: 0.978183776140213, Validation accuracy: 78.39506172839506%
# Epoch 2000/2000, Training loss: 0.9494147747755051, Training accuracy: 83.95061728395062%, Validation loss: 0.9730069935321808, Validation accuracy: 77.77777777777777%
# Validation accuracy (%) = 77.77777777777777
# For regularisation strength = 0.01
# Epoch 1/2000, Training loss: 1.3865579962730408, Training accuracy: 24.897119341563787%, Validation loss: 1.3860464692115784, Validation accuracy: 25.308641975308642%
# Epoch 50/2000, Training loss: 1.3844959437847137, Training accuracy: 26.954732510288064%, Validation loss: 1.3874908089637756, Validation accuracy: 25.308641975308642%
# Epoch 100/2000, Training loss: 1.3778148293495178, Training accuracy: 26.954732510288064%, Validation loss: 1.3800329566001892, Validation accuracy: 32.098765432098766%
# Epoch 150/2000, Training loss: 1.3166898488998413, Training accuracy: 42.592592592592595%, Validation loss: 1.3103028535842896, Validation accuracy: 41.358024691358025%
# Epoch 200/2000, Training loss: 1.2461021840572357, Training accuracy: 47.53086419753087%, Validation loss: 1.2426753640174866, Validation accuracy: 47.53086419753087%
# Epoch 250/2000, Training loss: 1.2082298398017883, Training accuracy: 59.25925925925926%, Validation loss: 1.2074278593063354, Validation accuracy: 55.55555555555556%
# Epoch 300/2000, Training loss: 1.1821517050266266, Training accuracy: 60.49382716049383%, Validation loss: 1.1831579804420471, Validation accuracy: 56.79012345679013%
# Epoch 350/2000, Training loss: 1.161741316318512, Training accuracy: 62.34567901234568%, Validation loss: 1.1682072877883911, Validation accuracy: 59.876543209876544%
# Epoch 400/2000, Training loss: 1.1420942842960358, Training accuracy: 63.58024691358025%, Validation loss: 1.1493950486183167, Validation accuracy: 58.641975308641975%
# Epoch 450/2000, Training loss: 1.1285967528820038, Training accuracy: 63.16872427983539%, Validation loss: 1.1385070085525513, Validation accuracy: 59.876543209876544%
# Epoch 500/2000, Training loss: 1.1127721071243286, Training accuracy: 65.22633744855968%, Validation loss: 1.1268996000289917, Validation accuracy: 60.49382716049383%
# Epoch 550/2000, Training loss: 1.1035106778144836, Training accuracy: 66.46090534979425%, Validation loss: 1.1163934469223022, Validation accuracy: 61.111111111111114%
# Epoch 600/2000, Training loss: 1.095333993434906, Training accuracy: 65.84362139917695%, Validation loss: 1.104365348815918, Validation accuracy: 64.19753086419753%
# Epoch 650/2000, Training loss: 1.0827795565128326, Training accuracy: 68.3127572016461%, Validation loss: 1.0941211581230164, Validation accuracy: 64.19753086419753%
# Epoch 700/2000, Training loss: 1.072581946849823, Training accuracy: 68.10699588477367%, Validation loss: 1.083203673362732, Validation accuracy: 67.90123456790124%
# Epoch 750/2000, Training loss: 1.0687719881534576, Training accuracy: 67.90123456790124%, Validation loss: 1.0748385190963745, Validation accuracy: 67.28395061728395%
# Epoch 800/2000, Training loss: 1.0534024238586426, Training accuracy: 71.19341563786008%, Validation loss: 1.0646759867668152, Validation accuracy: 69.1358024691358%
# Epoch 850/2000, Training loss: 1.0478945672512054, Training accuracy: 71.60493827160494%, Validation loss: 1.0557522773742676, Validation accuracy: 67.28395061728395%
# Epoch 900/2000, Training loss: 1.0393742620944977, Training accuracy: 72.63374485596708%, Validation loss: 1.0472712516784668, Validation accuracy: 69.1358024691358%
# Epoch 950/2000, Training loss: 1.0326546132564545, Training accuracy: 73.86831275720165%, Validation loss: 1.036562979221344, Validation accuracy: 69.1358024691358%
# Epoch 1000/2000, Training loss: 1.0253092348575592, Training accuracy: 75.51440329218107%, Validation loss: 1.0257967114448547, Validation accuracy: 73.45679012345678%
# Epoch 1050/2000, Training loss: 1.014104276895523, Training accuracy: 76.33744855967078%, Validation loss: 1.0165972709655762, Validation accuracy: 75.92592592592592%
# Epoch 1100/2000, Training loss: 1.0121224522590637, Training accuracy: 76.13168724279835%, Validation loss: 1.0111276507377625, Validation accuracy: 73.45679012345678%
# Epoch 1150/2000, Training loss: 1.0028889924287796, Training accuracy: 76.95473251028807%, Validation loss: 0.999021053314209, Validation accuracy: 75.92592592592592%
# Epoch 1200/2000, Training loss: 0.9962212145328522, Training accuracy: 80.45267489711934%, Validation loss: 0.9894957542419434, Validation accuracy: 78.39506172839506%
# Epoch 1250/2000, Training loss: 0.9894888699054718, Training accuracy: 79.01234567901234%, Validation loss: 0.9794776141643524, Validation accuracy: 78.39506172839506%
# Epoch 1300/2000, Training loss: 0.9815834164619446, Training accuracy: 80.04115226337449%, Validation loss: 0.970764547586441, Validation accuracy: 80.8641975308642%
# Epoch 1350/2000, Training loss: 0.974089577794075, Training accuracy: 81.48148148148148%, Validation loss: 0.9673388302326202, Validation accuracy: 81.48148148148148%
# Epoch 1400/2000, Training loss: 0.9674463123083115, Training accuracy: 80.65843621399176%, Validation loss: 0.960851788520813, Validation accuracy: 81.48148148148148%
# Epoch 1450/2000, Training loss: 0.96559277176857, Training accuracy: 82.3045267489712%, Validation loss: 0.9499806761741638, Validation accuracy: 84.5679012345679%
# Epoch 1500/2000, Training loss: 0.9586746394634247, Training accuracy: 82.92181069958848%, Validation loss: 0.9429580271244049, Validation accuracy: 83.95061728395062%
# Epoch 1550/2000, Training loss: 0.9522498995065689, Training accuracy: 83.33333333333333%, Validation loss: 0.9433818161487579, Validation accuracy: 84.5679012345679%
# Epoch 1600/2000, Training loss: 0.951099693775177, Training accuracy: 83.7448559670782%, Validation loss: 0.9338957965373993, Validation accuracy: 83.95061728395062%
# Epoch 1650/2000, Training loss: 0.9412133246660233, Training accuracy: 83.7448559670782%, Validation loss: 0.9287892878055573, Validation accuracy: 85.80246913580247%
# Epoch 1700/2000, Training loss: 0.9394032508134842, Training accuracy: 84.5679012345679%, Validation loss: 0.9212102890014648, Validation accuracy: 86.41975308641975%
# Epoch 1750/2000, Training loss: 0.9302529692649841, Training accuracy: 84.97942386831275%, Validation loss: 0.9154236018657684, Validation accuracy: 86.41975308641975%
# Epoch 1800/2000, Training loss: 0.9260070472955704, Training accuracy: 86.0082304526749%, Validation loss: 0.9087249040603638, Validation accuracy: 87.03703703703704%
# Epoch 1850/2000, Training loss: 0.9202825725078583, Training accuracy: 87.24279835390946%, Validation loss: 0.9051678478717804, Validation accuracy: 86.41975308641975%
# Epoch 1900/2000, Training loss: 0.9142826944589615, Training accuracy: 87.03703703703704%, Validation loss: 0.8947683572769165, Validation accuracy: 90.12345679012346%
# Epoch 1950/2000, Training loss: 0.9083759486675262, Training accuracy: 88.06584362139918%, Validation loss: 0.8935133516788483, Validation accuracy: 89.50617283950618%
# Epoch 2000/2000, Training loss: 0.9037013202905655, Training accuracy: 88.27160493827161%, Validation loss: 0.8866534531116486, Validation accuracy: 90.74074074074075%
# Validation accuracy (%) = 90.74074074074075
# For regularisation strength = 0.1
# Epoch 1/2000, Training loss: 1.3865527510643005, Training accuracy: 22.22222222222222%, Validation loss: 1.3860585689544678, Validation accuracy: 25.925925925925927%
# Epoch 50/2000, Training loss: 1.3846166133880615, Training accuracy: 26.954732510288064%, Validation loss: 1.3875937461853027, Validation accuracy: 25.308641975308642%
# Epoch 100/2000, Training loss: 1.3835539519786835, Training accuracy: 26.954732510288064%, Validation loss: 1.3865025639533997, Validation accuracy: 25.308641975308642%
# Epoch 150/2000, Training loss: 1.3139042258262634, Training accuracy: 39.300411522633745%, Validation loss: 1.320828139781952, Validation accuracy: 40.74074074074074%
# Epoch 200/2000, Training loss: 1.2126547992229462, Training accuracy: 51.440329218106996%, Validation loss: 1.2217731475830078, Validation accuracy: 48.76543209876543%
# Epoch 250/2000, Training loss: 1.167977511882782, Training accuracy: 62.34567901234568%, Validation loss: 1.1666730642318726, Validation accuracy: 61.111111111111114%
# Epoch 300/2000, Training loss: 1.1355155408382416, Training accuracy: 62.13991769547325%, Validation loss: 1.1387420892715454, Validation accuracy: 59.876543209876544%
# Epoch 350/2000, Training loss: 1.116508662700653, Training accuracy: 63.78600823045267%, Validation loss: 1.123799204826355, Validation accuracy: 62.96296296296296%
# Epoch 400/2000, Training loss: 1.1005140244960785, Training accuracy: 66.04938271604938%, Validation loss: 1.110594630241394, Validation accuracy: 63.58024691358025%
# Epoch 450/2000, Training loss: 1.089256763458252, Training accuracy: 66.8724279835391%, Validation loss: 1.1009361743927002, Validation accuracy: 64.19753086419753%
# Epoch 500/2000, Training loss: 1.077391117811203, Training accuracy: 67.48971193415638%, Validation loss: 1.0917404890060425, Validation accuracy: 65.4320987654321%
# Epoch 550/2000, Training loss: 1.0676706433296204, Training accuracy: 68.3127572016461%, Validation loss: 1.0826348662376404, Validation accuracy: 69.1358024691358%
# Epoch 600/2000, Training loss: 1.0593579411506653, Training accuracy: 70.78189300411523%, Validation loss: 1.0735501050949097, Validation accuracy: 69.75308641975309%
# Epoch 650/2000, Training loss: 1.052536964416504, Training accuracy: 71.60493827160494%, Validation loss: 1.0649362206459045, Validation accuracy: 69.75308641975309%
# Epoch 700/2000, Training loss: 1.0416095852851868, Training accuracy: 73.04526748971193%, Validation loss: 1.0565333366394043, Validation accuracy: 71.60493827160494%
# Epoch 750/2000, Training loss: 1.0318308174610138, Training accuracy: 73.86831275720165%, Validation loss: 1.0463916063308716, Validation accuracy: 70.98765432098766%
# Epoch 800/2000, Training loss: 1.0264454931020737, Training accuracy: 73.86831275720165%, Validation loss: 1.036086082458496, Validation accuracy: 72.8395061728395%
# Epoch 850/2000, Training loss: 1.0145418345928192, Training accuracy: 77.36625514403292%, Validation loss: 1.0243456363677979, Validation accuracy: 74.07407407407408%
# Epoch 900/2000, Training loss: 1.0056856572628021, Training accuracy: 78.18930041152264%, Validation loss: 1.015062689781189, Validation accuracy: 75.30864197530865%
# Epoch 950/2000, Training loss: 1.0004804879426956, Training accuracy: 79.21810699588477%, Validation loss: 1.0039129257202148, Validation accuracy: 79.01234567901234%
# Epoch 1000/2000, Training loss: 0.9874100834131241, Training accuracy: 80.45267489711934%, Validation loss: 0.9946820735931396, Validation accuracy: 77.77777777777777%
# Epoch 1050/2000, Training loss: 0.9814442843198776, Training accuracy: 80.65843621399176%, Validation loss: 0.9835498332977295, Validation accuracy: 78.39506172839506%
# Epoch 1100/2000, Training loss: 0.9739172905683517, Training accuracy: 83.53909465020575%, Validation loss: 0.9776891767978668, Validation accuracy: 79.01234567901234%
# Epoch 1150/2000, Training loss: 0.9660876095294952, Training accuracy: 84.5679012345679%, Validation loss: 0.9642170369625092, Validation accuracy: 85.18518518518519%
# Epoch 1200/2000, Training loss: 0.9568895697593689, Training accuracy: 86.0082304526749%, Validation loss: 0.9554430246353149, Validation accuracy: 82.71604938271605%
# Epoch 1250/2000, Training loss: 0.9498066008090973, Training accuracy: 86.0082304526749%, Validation loss: 0.946631133556366, Validation accuracy: 83.95061728395062%
# Epoch 1300/2000, Training loss: 0.9421459883451462, Training accuracy: 86.21399176954732%, Validation loss: 0.9381212890148163, Validation accuracy: 85.18518518518519%
# Epoch 1350/2000, Training loss: 0.9377312511205673, Training accuracy: 87.44855967078189%, Validation loss: 0.9328481256961823, Validation accuracy: 85.80246913580247%
# Epoch 1400/2000, Training loss: 0.9295596331357956, Training accuracy: 88.27160493827161%, Validation loss: 0.9256082773208618, Validation accuracy: 85.80246913580247%
# Epoch 1450/2000, Training loss: 0.9247722327709198, Training accuracy: 87.65432098765432%, Validation loss: 0.9187098741531372, Validation accuracy: 85.80246913580247%
# Epoch 1500/2000, Training loss: 0.9194310754537582, Training accuracy: 89.30041152263375%, Validation loss: 0.9109140038490295, Validation accuracy: 87.03703703703704%
# Epoch 1550/2000, Training loss: 0.9135598242282867, Training accuracy: 89.09465020576131%, Validation loss: 0.9055543839931488, Validation accuracy: 89.50617283950618%
# Epoch 1600/2000, Training loss: 0.9071813672780991, Training accuracy: 88.68312757201646%, Validation loss: 0.9002430438995361, Validation accuracy: 88.27160493827161%
# Epoch 1650/2000, Training loss: 0.8999038934707642, Training accuracy: 90.12345679012346%, Validation loss: 0.89374840259552, Validation accuracy: 89.50617283950618%
# Epoch 1700/2000, Training loss: 0.8958694636821747, Training accuracy: 89.91769547325103%, Validation loss: 0.8894340991973877, Validation accuracy: 88.88888888888889%
# Epoch 1750/2000, Training loss: 0.8903326690196991, Training accuracy: 91.35802469135803%, Validation loss: 0.8853685557842255, Validation accuracy: 88.27160493827161%
# Epoch 1800/2000, Training loss: 0.8865128308534622, Training accuracy: 91.35802469135803%, Validation loss: 0.877728670835495, Validation accuracy: 91.35802469135803%
# Epoch 1850/2000, Training loss: 0.8822357505559921, Training accuracy: 91.56378600823045%, Validation loss: 0.8737965226173401, Validation accuracy: 91.35802469135803%
# Epoch 1900/2000, Training loss: 0.8805407732725143, Training accuracy: 91.76954732510288%, Validation loss: 0.8710474371910095, Validation accuracy: 90.74074074074075%
# Epoch 1950/2000, Training loss: 0.8739597052335739, Training accuracy: 92.18106995884774%, Validation loss: 0.8647536039352417, Validation accuracy: 91.35802469135803%
# Epoch 2000/2000, Training loss: 0.8706501424312592, Training accuracy: 92.38683127572017%, Validation loss: 0.8613349497318268, Validation accuracy: 91.9753086419753%
# Validation accuracy (%) = 91.9753086419753
# For regularisation strength = 1
# Epoch 1/2000, Training loss: 1.3865025341510773, Training accuracy: 24.691358024691358%, Validation loss: 1.3865411281585693, Validation accuracy: 23.45679012345679%
# Epoch 50/2000, Training loss: 1.384047120809555, Training accuracy: 26.954732510288064%, Validation loss: 1.3877784609794617, Validation accuracy: 25.308641975308642%
# Epoch 100/2000, Training loss: 1.382491558790207, Training accuracy: 26.954732510288064%, Validation loss: 1.384414255619049, Validation accuracy: 25.308641975308642%
# Epoch 150/2000, Training loss: 1.3459937572479248, Training accuracy: 38.065843621399175%, Validation loss: 1.3384625911712646, Validation accuracy: 42.592592592592595%
# Epoch 200/2000, Training loss: 1.2345314621925354, Training accuracy: 48.97119341563786%, Validation loss: 1.2249545454978943, Validation accuracy: 49.382716049382715%
# Epoch 250/2000, Training loss: 1.1724315583705902, Training accuracy: 65.22633744855968%, Validation loss: 1.1700007915496826, Validation accuracy: 64.19753086419753%
# Epoch 300/2000, Training loss: 1.1322867274284363, Training accuracy: 66.2551440329218%, Validation loss: 1.1324978470802307, Validation accuracy: 66.04938271604938%
# Epoch 350/2000, Training loss: 1.1017372608184814, Training accuracy: 69.34156378600824%, Validation loss: 1.1027039885520935, Validation accuracy: 69.75308641975309%
# Epoch 400/2000, Training loss: 1.076454609632492, Training accuracy: 70.57613168724279%, Validation loss: 1.0824570059776306, Validation accuracy: 71.60493827160494%
# Epoch 450/2000, Training loss: 1.0566296577453613, Training accuracy: 72.42798353909465%, Validation loss: 1.065684199333191, Validation accuracy: 70.98765432098766%
# Epoch 500/2000, Training loss: 1.0403723418712616, Training accuracy: 73.86831275720165%, Validation loss: 1.0499610304832458, Validation accuracy: 73.45679012345678%
# Epoch 550/2000, Training loss: 1.0310581028461456, Training accuracy: 74.2798353909465%, Validation loss: 1.0341928601264954, Validation accuracy: 74.07407407407408%
# Epoch 600/2000, Training loss: 1.0153551995754242, Training accuracy: 76.95473251028807%, Validation loss: 1.0212339758872986, Validation accuracy: 72.22222222222223%
# Epoch 650/2000, Training loss: 1.00459523499012, Training accuracy: 78.18930041152264%, Validation loss: 1.0078216791152954, Validation accuracy: 74.69135802469135%
# Epoch 700/2000, Training loss: 0.9963320940732956, Training accuracy: 79.42386831275721%, Validation loss: 0.995793491601944, Validation accuracy: 77.77777777777777%
# Epoch 750/2000, Training loss: 0.9857254773378372, Training accuracy: 81.27572016460906%, Validation loss: 0.9757115244865417, Validation accuracy: 79.01234567901234%
# Epoch 800/2000, Training loss: 0.9775284230709076, Training accuracy: 80.45267489711934%, Validation loss: 0.9640170633792877, Validation accuracy: 79.62962962962963%
# Epoch 850/2000, Training loss: 0.9694133549928665, Training accuracy: 83.33333333333333%, Validation loss: 0.953037440776825, Validation accuracy: 81.48148148148148%
# Epoch 900/2000, Training loss: 0.9590621888637543, Training accuracy: 83.7448559670782%, Validation loss: 0.9476566314697266, Validation accuracy: 82.09876543209876%
# Epoch 950/2000, Training loss: 0.9514183849096298, Training accuracy: 84.97942386831275%, Validation loss: 0.9338535666465759, Validation accuracy: 84.5679012345679%
# Epoch 1000/2000, Training loss: 0.9423801004886627, Training accuracy: 85.59670781893004%, Validation loss: 0.9231366813182831, Validation accuracy: 86.41975308641975%
# Epoch 1050/2000, Training loss: 0.9346256405115128, Training accuracy: 86.21399176954732%, Validation loss: 0.915160596370697, Validation accuracy: 87.65432098765432%
# Epoch 1100/2000, Training loss: 0.9248989969491959, Training accuracy: 87.65432098765432%, Validation loss: 0.9039406776428223, Validation accuracy: 88.27160493827161%
# Epoch 1150/2000, Training loss: 0.9143235981464386, Training accuracy: 88.68312757201646%, Validation loss: 0.8948752582073212, Validation accuracy: 90.12345679012346%
# Epoch 1200/2000, Training loss: 0.9089640527963638, Training accuracy: 89.7119341563786%, Validation loss: 0.8903053402900696, Validation accuracy: 88.27160493827161%
# Epoch 1250/2000, Training loss: 0.9019860178232193, Training accuracy: 91.56378600823045%, Validation loss: 0.8794667720794678, Validation accuracy: 90.12345679012346%
# Epoch 1300/2000, Training loss: 0.8961616903543472, Training accuracy: 91.9753086419753%, Validation loss: 0.8758575022220612, Validation accuracy: 90.74074074074075%
# Epoch 1350/2000, Training loss: 0.8921739459037781, Training accuracy: 92.79835390946502%, Validation loss: 0.871425211429596, Validation accuracy: 90.74074074074075%
# Epoch 1400/2000, Training loss: 0.8863029927015305, Training accuracy: 93.4156378600823%, Validation loss: 0.8680956065654755, Validation accuracy: 90.74074074074075%
# Epoch 1450/2000, Training loss: 0.8802539110183716, Training accuracy: 94.23868312757202%, Validation loss: 0.8575902283191681, Validation accuracy: 92.5925925925926%
# Epoch 1500/2000, Training loss: 0.8752635717391968, Training accuracy: 93.62139917695474%, Validation loss: 0.8527388572692871, Validation accuracy: 93.20987654320987%
# Epoch 1550/2000, Training loss: 0.8686354905366898, Training accuracy: 94.23868312757202%, Validation loss: 0.8489530682563782, Validation accuracy: 93.20987654320987%
# Epoch 1600/2000, Training loss: 0.8648735731840134, Training accuracy: 93.62139917695474%, Validation loss: 0.8439221084117889, Validation accuracy: 93.20987654320987%
# Epoch 1650/2000, Training loss: 0.8630757331848145, Training accuracy: 93.4156378600823%, Validation loss: 0.8452185690402985, Validation accuracy: 91.9753086419753%
# Epoch 1700/2000, Training loss: 0.8594040125608444, Training accuracy: 93.82716049382717%, Validation loss: 0.8416412174701691, Validation accuracy: 93.20987654320987%
# Epoch 1750/2000, Training loss: 0.8554911613464355, Training accuracy: 93.82716049382717%, Validation loss: 0.8323469460010529, Validation accuracy: 95.06172839506173%
# Epoch 1800/2000, Training loss: 0.8519212305545807, Training accuracy: 93.82716049382717%, Validation loss: 0.8307512104511261, Validation accuracy: 93.82716049382717%
# Epoch 1850/2000, Training loss: 0.8487804532051086, Training accuracy: 94.23868312757202%, Validation loss: 0.826583057641983, Validation accuracy: 95.06172839506173%
# Epoch 1900/2000, Training loss: 0.8441228419542313, Training accuracy: 94.23868312757202%, Validation loss: 0.8255047798156738, Validation accuracy: 95.06172839506173%
# Epoch 1950/2000, Training loss: 0.8448269069194794, Training accuracy: 94.03292181069959%, Validation loss: 0.8209714591503143, Validation accuracy: 95.06172839506173%
# Epoch 2000/2000, Training loss: 0.8407590240240097, Training accuracy: 94.44444444444444%, Validation loss: 0.821860134601593, Validation accuracy: 94.44444444444444%
# Validation accuracy (%) = 94.44444444444444
# For regularisation strength = 10
# Epoch 1/2000, Training loss: 1.386107176542282, Training accuracy: 25.925925925925927%, Validation loss: 1.3864337801933289, Validation accuracy: 25.308641975308642%
# Epoch 50/2000, Training loss: 1.3814773857593536, Training accuracy: 26.954732510288064%, Validation loss: 1.3840516209602356, Validation accuracy: 25.308641975308642%
# Epoch 100/2000, Training loss: 1.2674829363822937, Training accuracy: 45.47325102880659%, Validation loss: 1.2641306519508362, Validation accuracy: 44.44444444444444%
# Epoch 150/2000, Training loss: 1.1810071170330048, Training accuracy: 60.288065843621396%, Validation loss: 1.1972723603248596, Validation accuracy: 51.23456790123457%
# Epoch 200/2000, Training loss: 1.1395178437232971, Training accuracy: 62.96296296296296%, Validation loss: 1.1689246892929077, Validation accuracy: 57.407407407407405%
# Epoch 250/2000, Training loss: 1.1111393570899963, Training accuracy: 65.4320987654321%, Validation loss: 1.152375340461731, Validation accuracy: 56.79012345679013%
# Epoch 300/2000, Training loss: 1.0958013534545898, Training accuracy: 66.8724279835391%, Validation loss: 1.141710877418518, Validation accuracy: 57.407407407407405%
# Epoch 350/2000, Training loss: 1.0829779505729675, Training accuracy: 68.51851851851852%, Validation loss: 1.1333866119384766, Validation accuracy: 58.641975308641975%
# Epoch 400/2000, Training loss: 1.0681854337453842, Training accuracy: 68.93004115226337%, Validation loss: 1.1270138621330261, Validation accuracy: 59.876543209876544%
# Epoch 450/2000, Training loss: 1.0598579049110413, Training accuracy: 69.95884773662551%, Validation loss: 1.120932698249817, Validation accuracy: 61.72839506172839%
# Epoch 500/2000, Training loss: 1.052173227071762, Training accuracy: 71.60493827160494%, Validation loss: 1.113387405872345, Validation accuracy: 61.111111111111114%
# Epoch 550/2000, Training loss: 1.044994056224823, Training accuracy: 72.8395061728395%, Validation loss: 1.107175886631012, Validation accuracy: 63.58024691358025%
# Epoch 600/2000, Training loss: 1.034252256155014, Training accuracy: 74.07407407407408%, Validation loss: 1.1021931171417236, Validation accuracy: 64.19753086419753%
# Epoch 650/2000, Training loss: 1.0287552624940872, Training accuracy: 74.69135802469135%, Validation loss: 1.093569278717041, Validation accuracy: 66.66666666666667%
# Epoch 700/2000, Training loss: 1.019673764705658, Training accuracy: 75.51440329218107%, Validation loss: 1.0866914987564087, Validation accuracy: 68.51851851851852%
# Epoch 750/2000, Training loss: 1.0110570788383484, Training accuracy: 75.51440329218107%, Validation loss: 1.082529067993164, Validation accuracy: 66.66666666666667%
# Epoch 800/2000, Training loss: 1.0050403326749802, Training accuracy: 75.92592592592592%, Validation loss: 1.0762113332748413, Validation accuracy: 66.66666666666667%
# Epoch 850/2000, Training loss: 0.9980240762233734, Training accuracy: 76.95473251028807%, Validation loss: 1.064888834953308, Validation accuracy: 68.51851851851852%
# Epoch 900/2000, Training loss: 0.9970042854547501, Training accuracy: 76.95473251028807%, Validation loss: 1.0611222386360168, Validation accuracy: 67.28395061728395%
# Epoch 950/2000, Training loss: 0.9817546755075455, Training accuracy: 78.39506172839506%, Validation loss: 1.0487934947013855, Validation accuracy: 69.1358024691358%
# Epoch 1000/2000, Training loss: 0.9789174646139145, Training accuracy: 78.80658436213992%, Validation loss: 1.0371864438056946, Validation accuracy: 70.37037037037037%
# Epoch 1050/2000, Training loss: 0.9710506051778793, Training accuracy: 79.83539094650206%, Validation loss: 1.0288585424423218, Validation accuracy: 69.75308641975309%
# Epoch 1100/2000, Training loss: 0.9686501324176788, Training accuracy: 79.83539094650206%, Validation loss: 1.0190885066986084, Validation accuracy: 72.8395061728395%
# Epoch 1150/2000, Training loss: 0.9609915018081665, Training accuracy: 80.24691358024691%, Validation loss: 1.010562539100647, Validation accuracy: 73.45679012345678%
# Epoch 1200/2000, Training loss: 0.9549718499183655, Training accuracy: 81.6872427983539%, Validation loss: 0.9985250234603882, Validation accuracy: 74.07407407407408%
# Epoch 1250/2000, Training loss: 0.9510240107774734, Training accuracy: 82.92181069958848%, Validation loss: 0.9890159666538239, Validation accuracy: 76.54320987654322%
# Epoch 1300/2000, Training loss: 0.9444742351770401, Training accuracy: 83.33333333333333%, Validation loss: 0.9789227545261383, Validation accuracy: 78.39506172839506%
# Epoch 1350/2000, Training loss: 0.9438995569944382, Training accuracy: 83.7448559670782%, Validation loss: 0.9702548384666443, Validation accuracy: 78.39506172839506%
# Epoch 1400/2000, Training loss: 0.9317286908626556, Training accuracy: 84.5679012345679%, Validation loss: 0.9622664451599121, Validation accuracy: 80.24691358024691%
# Epoch 1450/2000, Training loss: 0.9293546825647354, Training accuracy: 85.18518518518519%, Validation loss: 0.9554138779640198, Validation accuracy: 81.48148148148148%
# Epoch 1500/2000, Training loss: 0.9203324168920517, Training accuracy: 85.59670781893004%, Validation loss: 0.9467852115631104, Validation accuracy: 82.09876543209876%
# Epoch 1550/2000, Training loss: 0.9192872941493988, Training accuracy: 85.80246913580247%, Validation loss: 0.9408065378665924, Validation accuracy: 82.09876543209876%
# Epoch 1600/2000, Training loss: 0.908416286110878, Training accuracy: 87.65432098765432%, Validation loss: 0.930945485830307, Validation accuracy: 83.33333333333333%
# Epoch 1650/2000, Training loss: 0.9019980281591415, Training accuracy: 88.47736625514403%, Validation loss: 0.9266779124736786, Validation accuracy: 84.5679012345679%
# Epoch 1700/2000, Training loss: 0.8997620642185211, Training accuracy: 89.09465020576131%, Validation loss: 0.921737939119339, Validation accuracy: 85.18518518518519%
# Epoch 1750/2000, Training loss: 0.8959321230649948, Training accuracy: 88.68312757201646%, Validation loss: 0.91947340965271, Validation accuracy: 85.18518518518519%
# Epoch 1800/2000, Training loss: 0.8862856179475784, Training accuracy: 89.7119341563786%, Validation loss: 0.9132109582424164, Validation accuracy: 85.18518518518519%
# Epoch 1850/2000, Training loss: 0.8828759342432022, Training accuracy: 89.30041152263375%, Validation loss: 0.9077562391757965, Validation accuracy: 85.18518518518519%
# Epoch 1900/2000, Training loss: 0.8803656697273254, Training accuracy: 89.7119341563786%, Validation loss: 0.9036959409713745, Validation accuracy: 85.80246913580247%
# Epoch 1950/2000, Training loss: 0.8764104247093201, Training accuracy: 90.12345679012346%, Validation loss: 0.8984622061252594, Validation accuracy: 86.41975308641975%
# Epoch 2000/2000, Training loss: 0.876251682639122, Training accuracy: 90.12345679012346%, Validation loss: 0.8968897759914398, Validation accuracy: 86.41975308641975%
# Validation accuracy (%) = 86.41975308641975
# The optimal regularisation strength is 1

# %% [markdown]
# ---

# %% [markdown]
# The optimal regularisation strength is determined by looking at the scenario in which the validation accuracy is maximised. In this case, the optimal value is 1. I now proceed to re-train the CNN on the training set and evaluate the classification accuracy on the test set.

# %%
model, criterion, optimiser = get_model(x_train, n_filters, k, pool_size, stride_pool, classes) ## <-- SOLUTION
history = training_loop(model, train_loader, val_loader, criterion, optimiser, max_num_epochs, max_patience, reg_strength=opt_reg_strength)
# Out:
# Epoch 1/2000, Training loss: 1.3862003087997437, Training accuracy: 26.954732510288064%, Validation loss: 1.3863494992256165, Validation accuracy: 25.308641975308642%
# Epoch 50/2000, Training loss: 1.3850637078285217, Training accuracy: 26.954732510288064%, Validation loss: 1.3875056505203247, Validation accuracy: 25.308641975308642%
# Epoch 100/2000, Training loss: 1.3823752403259277, Training accuracy: 26.954732510288064%, Validation loss: 1.385685682296753, Validation accuracy: 25.308641975308642%
# Epoch 150/2000, Training loss: 1.3568438291549683, Training accuracy: 35.59670781893004%, Validation loss: 1.357023000717163, Validation accuracy: 34.5679012345679%
# Epoch 200/2000, Training loss: 1.2996405363082886, Training accuracy: 40.32921810699588%, Validation loss: 1.2944279909133911, Validation accuracy: 37.03703703703704%
# Epoch 250/2000, Training loss: 1.2610729038715363, Training accuracy: 42.181069958847736%, Validation loss: 1.256291925907135, Validation accuracy: 41.358024691358025%
# Epoch 300/2000, Training loss: 1.2367760241031647, Training accuracy: 48.97119341563786%, Validation loss: 1.2354060411453247, Validation accuracy: 47.53086419753087%
# Epoch 350/2000, Training loss: 1.2181828022003174, Training accuracy: 51.23456790123457%, Validation loss: 1.2187644243240356, Validation accuracy: 47.53086419753087%
# Epoch 400/2000, Training loss: 1.1997274160385132, Training accuracy: 54.52674897119341%, Validation loss: 1.2047227621078491, Validation accuracy: 50.617283950617285%
# Epoch 450/2000, Training loss: 1.1891034543514252, Training accuracy: 54.52674897119341%, Validation loss: 1.1908267736434937, Validation accuracy: 53.7037037037037%
# Epoch 500/2000, Training loss: 1.1710114479064941, Training accuracy: 60.699588477366255%, Validation loss: 1.1833536624908447, Validation accuracy: 55.55555555555556%
# Epoch 550/2000, Training loss: 1.1559763550758362, Training accuracy: 60.288065843621396%, Validation loss: 1.176452875137329, Validation accuracy: 56.17283950617284%
# Epoch 600/2000, Training loss: 1.143789142370224, Training accuracy: 63.37448559670782%, Validation loss: 1.16573166847229, Validation accuracy: 54.93827160493827%
# Epoch 650/2000, Training loss: 1.1308890283107758, Training accuracy: 63.991769547325106%, Validation loss: 1.1548285484313965, Validation accuracy: 56.17283950617284%
# Epoch 700/2000, Training loss: 1.1210758686065674, Training accuracy: 64.40329218106996%, Validation loss: 1.149921715259552, Validation accuracy: 56.17283950617284%
# Epoch 750/2000, Training loss: 1.1128781735897064, Training accuracy: 65.63786008230453%, Validation loss: 1.1428260207176208, Validation accuracy: 60.49382716049383%
# Epoch 800/2000, Training loss: 1.1026212573051453, Training accuracy: 66.04938271604938%, Validation loss: 1.1326028108596802, Validation accuracy: 58.641975308641975%
# Epoch 850/2000, Training loss: 1.0947643518447876, Training accuracy: 66.04938271604938%, Validation loss: 1.1227859854698181, Validation accuracy: 62.34567901234568%
# Epoch 900/2000, Training loss: 1.088380515575409, Training accuracy: 67.07818930041152%, Validation loss: 1.1162136793136597, Validation accuracy: 65.4320987654321%
# Epoch 950/2000, Training loss: 1.0821651220321655, Training accuracy: 68.10699588477367%, Validation loss: 1.111636459827423, Validation accuracy: 59.876543209876544%
# Epoch 1000/2000, Training loss: 1.0741081833839417, Training accuracy: 68.10699588477367%, Validation loss: 1.1000460982322693, Validation accuracy: 66.66666666666667%
# Epoch 1050/2000, Training loss: 1.0706776976585388, Training accuracy: 69.75308641975309%, Validation loss: 1.0965693593025208, Validation accuracy: 65.4320987654321%
# Epoch 1100/2000, Training loss: 1.064094066619873, Training accuracy: 70.78189300411523%, Validation loss: 1.0882527828216553, Validation accuracy: 66.66666666666667%
# Epoch 1150/2000, Training loss: 1.057979792356491, Training accuracy: 71.39917695473251%, Validation loss: 1.0822305083274841, Validation accuracy: 67.28395061728395%
# Epoch 1200/2000, Training loss: 1.0553355813026428, Training accuracy: 71.60493827160494%, Validation loss: 1.0801414847373962, Validation accuracy: 66.66666666666667%
# Epoch 1250/2000, Training loss: 1.045954316854477, Training accuracy: 72.01646090534979%, Validation loss: 1.0728287100791931, Validation accuracy: 68.51851851851852%
# Epoch 1300/2000, Training loss: 1.044727385044098, Training accuracy: 72.01646090534979%, Validation loss: 1.0663248896598816, Validation accuracy: 70.37037037037037%
# Epoch 1350/2000, Training loss: 1.039010688662529, Training accuracy: 73.45679012345678%, Validation loss: 1.0573683977127075, Validation accuracy: 69.75308641975309%
# Epoch 1400/2000, Training loss: 1.0376036167144775, Training accuracy: 73.25102880658436%, Validation loss: 1.0556851625442505, Validation accuracy: 71.60493827160494%
# Epoch 1450/2000, Training loss: 1.0304135084152222, Training accuracy: 75.10288065843622%, Validation loss: 1.0467244386672974, Validation accuracy: 70.98765432098766%
# Epoch 1500/2000, Training loss: 1.0292226821184158, Training accuracy: 74.48559670781893%, Validation loss: 1.0455578565597534, Validation accuracy: 72.22222222222223%
# Epoch 1550/2000, Training loss: 1.0223336070775986, Training accuracy: 75.30864197530865%, Validation loss: 1.0394832491874695, Validation accuracy: 70.98765432098766%
# Epoch 1600/2000, Training loss: 1.0183843672275543, Training accuracy: 74.07407407407408%, Validation loss: 1.0381141304969788, Validation accuracy: 71.60493827160494%
# Epoch 1650/2000, Training loss: 1.0118665546178818, Training accuracy: 75.51440329218107%, Validation loss: 1.0307615399360657, Validation accuracy: 72.8395061728395%
# Epoch 1700/2000, Training loss: 1.0081986486911774, Training accuracy: 76.13168724279835%, Validation loss: 1.0278528928756714, Validation accuracy: 72.8395061728395%
# Epoch 1750/2000, Training loss: 1.0070769786834717, Training accuracy: 76.33744855967078%, Validation loss: 1.020956575870514, Validation accuracy: 74.07407407407408%
# Epoch 1800/2000, Training loss: 1.000263750553131, Training accuracy: 76.95473251028807%, Validation loss: 1.016467273235321, Validation accuracy: 72.8395061728395%
# Epoch 1850/2000, Training loss: 0.9933138340711594, Training accuracy: 77.36625514403292%, Validation loss: 1.0133426785469055, Validation accuracy: 74.69135802469135%
# Epoch 1900/2000, Training loss: 0.9876502901315689, Training accuracy: 80.04115226337449%, Validation loss: 1.003465473651886, Validation accuracy: 75.92592592592592%
# Epoch 1950/2000, Training loss: 0.9831487834453583, Training accuracy: 79.83539094650206%, Validation loss: 0.9974624812602997, Validation accuracy: 78.39506172839506%
# Epoch 2000/2000, Training loss: 0.97905433177948, Training accuracy: 80.24691358024691%, Validation loss: 0.9933023452758789, Validation accuracy: 79.62962962962963%

# %%
plot_loss_accuracy(history)

# %%
test_accuracy = evaluate_model(model, x_test, y_test)
print(f'The test accuracy is {test_accuracy}%.')
# Out:
# The test accuracy is 81.25%.

# %% [markdown]
# Training the CNN with L2 regularisation at its optimal strength results in a slight performance drop. In this case, convergence is not evident, but the separation between training and validation learning curves remains similar to the previous case. This suggests that additional training may be required for better stability and performance.

# %% [markdown]
# <a name="task-13b"></a>
#
# ## (1.3, BSc/3rd-year students only) [(index)](#index-task-13b)

# %% [markdown]
# I create the requested imbalanced training set by randomly dropping half of the data points in class 3 (M5V) from the original training set. I split the resulting dataset into 75% for actual training and 25% for validation.

# %%
np.random.seed(0)
class_3_indices = np.where(star_classes_train == 3)[0]
selected_indices = np.random.choice(class_3_indices, len(class_3_indices) // 2, replace=False)
remaining_indices = np.setdiff1d(np.arange(len(star_classes_train)), selected_indices)

x_train_imbalanced = star_images_train[remaining_indices]
y_train_imbalanced = star_classes_train[remaining_indices]

x_train, y_train, x_val, y_val = dataset_split(x_train_imbalanced, y_train_imbalanced, val_size)
train_loader, val_loader = create_dataloaders(x_train, y_train, x_val, y_val, batch_size=128)
model, criterion, optimiser = get_model(x_train, n_filters, k, pool_size, stride_pool, classes)
history_imbalanced = training_loop(model, train_loader, val_loader, criterion, optimiser, max_num_epochs, max_patience)
plot_loss_accuracy(history_imbalanced)
# Out:
# Epoch 1/2000, Training loss: 1.3874859511852264, Training accuracy: 19.953051643192488%, Validation loss: 1.3867103457450867, Validation accuracy: 21.830985915492956%
# Epoch 50/2000, Training loss: 1.3563565015792847, Training accuracy: 30.985915492957748%, Validation loss: 1.4094905853271484, Validation accuracy: 21.830985915492956%
# Epoch 100/2000, Training loss: 1.3505320847034454, Training accuracy: 30.516431924882628%, Validation loss: 1.4114484190940857, Validation accuracy: 21.830985915492956%
# Epoch 150/2000, Training loss: 1.3535517156124115, Training accuracy: 30.985915492957748%, Validation loss: 1.413402497768402, Validation accuracy: 21.830985915492956%
# Early stopping acting.

# %% [markdown]
# Now the performance has drastically dropped. I modify the loss function by assigning the weight of each class to be the reciprocal of the class frequency.

# %%
weights = torch.tensor(1.0 / np.bincount(y_train), dtype=torch.float32)
criterion_weighted = CrossEntropyLoss(weight=weights)

model_weighted, criterion_weighted, optimiser_weighted = get_model(x_train, n_filters, k, pool_size, stride_pool, classes)
history_weighted = training_loop(model_weighted, train_loader, val_loader, criterion_weighted, optimiser_weighted, max_num_epochs, max_patience)
plot_loss_accuracy(history_weighted)
# Out:
# Epoch 1/2000, Training loss: 1.3835818767547607, Training accuracy: 24.88262910798122%, Validation loss: 1.3895622491836548, Validation accuracy: 29.577464788732396%
# Epoch 50/2000, Training loss: 1.3573632836341858, Training accuracy: 30.985915492957748%, Validation loss: 1.4112478494644165, Validation accuracy: 21.830985915492956%
# Epoch 100/2000, Training loss: 1.3530766367912292, Training accuracy: 30.516431924882628%, Validation loss: 1.415050446987152, Validation accuracy: 29.577464788732396%
# Epoch 150/2000, Training loss: 1.3541627824306488, Training accuracy: 30.985915492957748%, Validation loss: 1.4139904379844666, Validation accuracy: 21.830985915492956%
# Early stopping acting.

# %% [markdown]
# Utilising a reweighted loss function does not seem to be enough to recover performance. As a second approach, I produce new training data of the minority class (Class 3) by using each image in the depleted class 3 to obtain an additional training image by adding Gaussian noise on each pixel drawn from the Gaussian distribution. I scan several noise levels and find the optimal value of $c$ by cross-validation by looking at the highest validation accuracy.

# %%
c_values = [0.01, 0.1, 1]
optimal_c = None
best_val_acc = 0

for c in c_values:
    print('For c =', c)
    noise = np.random.normal(0, np.sqrt(c) * np.std(x_train_imbalanced[y_train_imbalanced == 3], axis=0), x_train_imbalanced[y_train_imbalanced == 3].shape)
    x_augmented = np.clip(x_train_imbalanced[y_train_imbalanced == 3] + noise, 0, 1)
    y_augmented = np.full(len(x_augmented), 3)

    x_train_augmented = np.concatenate((x_train_imbalanced, x_augmented), axis=0)
    y_train_augmented = np.concatenate((y_train_imbalanced, y_augmented), axis=0)

    x_train_aug, y_train_aug, x_val_aug, y_val_aug = dataset_split(x_train_augmented, y_train_augmented, val_size)
    train_aug_loader, val_aug_loader = create_dataloaders(x_train_aug, y_train_aug, x_val_aug, y_val_aug, batch_size=128)

    model_aug, criterion_aug, optimiser_aug = get_model(x_train, n_filters, k, pool_size, stride_pool, classes)
    history_aug = training_loop(model_aug, train_aug_loader, val_aug_loader, criterion_aug, optimiser_aug, max_num_epochs, max_patience)
    print('Validation accuracy (%) =', history_aug['validation_accuracy'][-1])

    if history_aug['validation_accuracy'][-1] > best_val_acc:
        best_val_acc = history_aug['validation_accuracy'][-1]
        optimal_c = c
# Out:
# For c = 0.01
# Epoch 1/2000, Training loss: 1.3866592049598694, Training accuracy: 24.640657084188913%, Validation loss: 1.3859768509864807, Validation accuracy: 23.45679012345679%
# Epoch 50/2000, Training loss: 1.3843060433864594, Training accuracy: 27.515400410677618%, Validation loss: 1.3880763053894043, Validation accuracy: 23.45679012345679%
# Epoch 100/2000, Training loss: 1.3844611048698425, Training accuracy: 27.515400410677618%, Validation loss: 1.3875165581703186, Validation accuracy: 23.45679012345679%
# Epoch 150/2000, Training loss: 1.3825713396072388, Training accuracy: 27.515400410677618%, Validation loss: 1.3852185606956482, Validation accuracy: 23.45679012345679%
# Epoch 200/2000, Training loss: 1.3359038829803467, Training accuracy: 42.299794661190965%, Validation loss: 1.3329736590385437, Validation accuracy: 40.123456790123456%
# Epoch 250/2000, Training loss: 1.2658808529376984, Training accuracy: 45.58521560574949%, Validation loss: 1.2599026560783386, Validation accuracy: 42.592592592592595%
# Epoch 300/2000, Training loss: 1.2303766012191772, Training accuracy: 48.87063655030801%, Validation loss: 1.219794750213623, Validation accuracy: 48.148148148148145%
# Epoch 350/2000, Training loss: 1.2073517441749573, Training accuracy: 53.18275154004107%, Validation loss: 1.1973503828048706, Validation accuracy: 51.23456790123457%
# Epoch 400/2000, Training loss: 1.191730409860611, Training accuracy: 55.23613963039014%, Validation loss: 1.1830915808677673, Validation accuracy: 52.46913580246913%
# Epoch 450/2000, Training loss: 1.1771023571491241, Training accuracy: 59.5482546201232%, Validation loss: 1.1683764457702637, Validation accuracy: 58.02469135802469%
# Epoch 500/2000, Training loss: 1.1605634689331055, Training accuracy: 62.83367556468173%, Validation loss: 1.15714031457901, Validation accuracy: 59.25925925925926%
# Epoch 550/2000, Training loss: 1.149567872285843, Training accuracy: 63.03901437371663%, Validation loss: 1.1443181037902832, Validation accuracy: 65.4320987654321%
# Epoch 600/2000, Training loss: 1.139012336730957, Training accuracy: 63.449691991786445%, Validation loss: 1.1343135833740234, Validation accuracy: 66.66666666666667%
# Epoch 650/2000, Training loss: 1.126297116279602, Training accuracy: 64.68172484599589%, Validation loss: 1.1231240630149841, Validation accuracy: 67.28395061728395%
# Epoch 700/2000, Training loss: 1.1207662522792816, Training accuracy: 64.8870636550308%, Validation loss: 1.1155371069908142, Validation accuracy: 65.4320987654321%
# Epoch 750/2000, Training loss: 1.107357144355774, Training accuracy: 66.94045174537987%, Validation loss: 1.109083116054535, Validation accuracy: 66.04938271604938%
# Epoch 800/2000, Training loss: 1.09801185131073, Training accuracy: 65.91375770020534%, Validation loss: 1.1024447679519653, Validation accuracy: 64.81481481481481%
# Epoch 850/2000, Training loss: 1.0930433571338654, Training accuracy: 66.94045174537987%, Validation loss: 1.0964033007621765, Validation accuracy: 69.1358024691358%
# Epoch 900/2000, Training loss: 1.0858858227729797, Training accuracy: 70.02053388090349%, Validation loss: 1.0918684601783752, Validation accuracy: 69.75308641975309%
# Epoch 950/2000, Training loss: 1.076968938112259, Training accuracy: 70.2258726899384%, Validation loss: 1.0844258666038513, Validation accuracy: 67.90123456790124%
# Epoch 1000/2000, Training loss: 1.0708191692829132, Training accuracy: 70.63655030800821%, Validation loss: 1.080578327178955, Validation accuracy: 67.90123456790124%
# Epoch 1050/2000, Training loss: 1.0636704862117767, Training accuracy: 72.07392197125257%, Validation loss: 1.0750510692596436, Validation accuracy: 70.98765432098766%
# Epoch 1100/2000, Training loss: 1.0568968653678894, Training accuracy: 72.27926078028747%, Validation loss: 1.0687907934188843, Validation accuracy: 71.60493827160494%
# Epoch 1150/2000, Training loss: 1.0530423820018768, Training accuracy: 71.66324435318275%, Validation loss: 1.0641536116600037, Validation accuracy: 72.22222222222223%
# Epoch 1200/2000, Training loss: 1.0405344367027283, Training accuracy: 74.33264887063655%, Validation loss: 1.0574966669082642, Validation accuracy: 72.22222222222223%
# Epoch 1250/2000, Training loss: 1.0350643694400787, Training accuracy: 75.15400410677618%, Validation loss: 1.053221344947815, Validation accuracy: 72.8395061728395%
# Epoch 1300/2000, Training loss: 1.0284524708986282, Training accuracy: 75.35934291581108%, Validation loss: 1.047139048576355, Validation accuracy: 72.8395061728395%
# Epoch 1350/2000, Training loss: 1.0223090946674347, Training accuracy: 75.97535934291581%, Validation loss: 1.0430242419242859, Validation accuracy: 74.69135802469135%
# Epoch 1400/2000, Training loss: 1.0208616256713867, Training accuracy: 75.35934291581108%, Validation loss: 1.0399495363235474, Validation accuracy: 74.07407407407408%
# Epoch 1450/2000, Training loss: 1.012932300567627, Training accuracy: 77.61806981519507%, Validation loss: 1.0368402600288391, Validation accuracy: 74.07407407407408%
# Epoch 1500/2000, Training loss: 1.0106188356876373, Training accuracy: 77.82340862422998%, Validation loss: 1.0318664908409119, Validation accuracy: 74.69135802469135%
# Epoch 1550/2000, Training loss: 1.0055324137210846, Training accuracy: 77.41273100616016%, Validation loss: 1.0280303955078125, Validation accuracy: 75.30864197530865%
# Epoch 1600/2000, Training loss: 1.0020807087421417, Training accuracy: 78.85010266940452%, Validation loss: 1.0244677662849426, Validation accuracy: 74.07407407407408%
# Epoch 1650/2000, Training loss: 0.9941211491823196, Training accuracy: 79.05544147843942%, Validation loss: 1.0205738544464111, Validation accuracy: 75.30864197530865%
# Epoch 1700/2000, Training loss: 0.9941462278366089, Training accuracy: 77.20739219712526%, Validation loss: 1.0172396302223206, Validation accuracy: 74.69135802469135%
# Epoch 1750/2000, Training loss: 0.9900705218315125, Training accuracy: 79.67145790554414%, Validation loss: 1.0131231546401978, Validation accuracy: 74.69135802469135%
# Epoch 1800/2000, Training loss: 0.9886647760868073, Training accuracy: 80.08213552361396%, Validation loss: 1.016353964805603, Validation accuracy: 75.92592592592592%
# Epoch 1850/2000, Training loss: 0.9803704172372818, Training accuracy: 80.08213552361396%, Validation loss: 1.0058414936065674, Validation accuracy: 75.30864197530865%
# Epoch 1900/2000, Training loss: 0.9745702296495438, Training accuracy: 81.10882956878851%, Validation loss: 1.0050568580627441, Validation accuracy: 77.1604938271605%
# Epoch 1950/2000, Training loss: 0.9729142636060715, Training accuracy: 81.51950718685832%, Validation loss: 1.0008788704872131, Validation accuracy: 77.1604938271605%
# Epoch 2000/2000, Training loss: 0.9694668799638748, Training accuracy: 81.93018480492813%, Validation loss: 0.9989139139652252, Validation accuracy: 76.54320987654322%
# Validation accuracy (%) = 76.54320987654322
# For c = 0.1
# Epoch 1/2000, Training loss: 1.3866926729679108, Training accuracy: 20.739219712525667%, Validation loss: 1.3858900666236877, Validation accuracy: 25.925925925925927%
# Epoch 50/2000, Training loss: 1.3834949731826782, Training accuracy: 27.515400410677618%, Validation loss: 1.387050986289978, Validation accuracy: 23.45679012345679%
# Epoch 100/2000, Training loss: 1.3579963445663452, Training accuracy: 39.42505133470226%, Validation loss: 1.358075201511383, Validation accuracy: 38.27160493827161%
# Epoch 150/2000, Training loss: 1.2800045311450958, Training accuracy: 45.790554414784395%, Validation loss: 1.2832014560699463, Validation accuracy: 38.888888888888886%
# Epoch 200/2000, Training loss: 1.2325327098369598, Training accuracy: 49.89733059548254%, Validation loss: 1.232005774974823, Validation accuracy: 45.06172839506173%
# Epoch 250/2000, Training loss: 1.2056025266647339, Training accuracy: 55.030800821355236%, Validation loss: 1.2032766938209534, Validation accuracy: 52.46913580246913%
# Epoch 300/2000, Training loss: 1.1877400279045105, Training accuracy: 57.49486652977413%, Validation loss: 1.1858728528022766, Validation accuracy: 53.08641975308642%
# Epoch 350/2000, Training loss: 1.174287348985672, Training accuracy: 59.3429158110883%, Validation loss: 1.1681197881698608, Validation accuracy: 58.02469135802469%
# Epoch 400/2000, Training loss: 1.1628694236278534, Training accuracy: 59.95893223819302%, Validation loss: 1.1544431447982788, Validation accuracy: 59.876543209876544%
# Epoch 450/2000, Training loss: 1.149974763393402, Training accuracy: 60.369609856262834%, Validation loss: 1.1415174007415771, Validation accuracy: 61.72839506172839%
# Epoch 500/2000, Training loss: 1.1435624063014984, Training accuracy: 61.39630390143737%, Validation loss: 1.1293493509292603, Validation accuracy: 62.34567901234568%
# Epoch 550/2000, Training loss: 1.1304801106452942, Training accuracy: 62.217659137577%, Validation loss: 1.1208624839782715, Validation accuracy: 63.58024691358025%
# Epoch 600/2000, Training loss: 1.1244274973869324, Training accuracy: 62.012320328542096%, Validation loss: 1.1132892370224, Validation accuracy: 64.19753086419753%
# Epoch 650/2000, Training loss: 1.1168778240680695, Training accuracy: 62.012320328542096%, Validation loss: 1.1074696779251099, Validation accuracy: 63.58024691358025%
# Epoch 700/2000, Training loss: 1.1108405590057373, Training accuracy: 63.860369609856264%, Validation loss: 1.0986023545265198, Validation accuracy: 66.04938271604938%
# Epoch 750/2000, Training loss: 1.1005111336708069, Training accuracy: 64.68172484599589%, Validation loss: 1.0924916863441467, Validation accuracy: 66.04938271604938%
# Epoch 800/2000, Training loss: 1.0945224165916443, Training accuracy: 65.29774127310061%, Validation loss: 1.0869301557540894, Validation accuracy: 68.51851851851852%
# Epoch 850/2000, Training loss: 1.0902847647666931, Training accuracy: 66.11909650924025%, Validation loss: 1.0832770466804504, Validation accuracy: 67.28395061728395%
# Epoch 900/2000, Training loss: 1.0800144374370575, Training accuracy: 67.35112936344969%, Validation loss: 1.0807016491889954, Validation accuracy: 66.04938271604938%
# Epoch 950/2000, Training loss: 1.0749020278453827, Training accuracy: 68.37782340862422%, Validation loss: 1.0802097916603088, Validation accuracy: 66.04938271604938%
# Epoch 1000/2000, Training loss: 1.0678352415561676, Training accuracy: 68.78850102669405%, Validation loss: 1.0759645700454712, Validation accuracy: 66.04938271604938%
# Epoch 1050/2000, Training loss: 1.0650382339954376, Training accuracy: 69.40451745379877%, Validation loss: 1.0734305381774902, Validation accuracy: 66.04938271604938%
# Epoch 1100/2000, Training loss: 1.0578218698501587, Training accuracy: 69.40451745379877%, Validation loss: 1.0706673860549927, Validation accuracy: 65.4320987654321%
# Epoch 1150/2000, Training loss: 1.0509517192840576, Training accuracy: 70.43121149897331%, Validation loss: 1.0687528252601624, Validation accuracy: 66.66666666666667%
# Epoch 1200/2000, Training loss: 1.0457352548837662, Training accuracy: 71.45790554414785%, Validation loss: 1.0689387321472168, Validation accuracy: 67.28395061728395%
# Epoch 1250/2000, Training loss: 1.0430180728435516, Training accuracy: 72.48459958932239%, Validation loss: 1.0649068355560303, Validation accuracy: 67.28395061728395%
# Epoch 1300/2000, Training loss: 1.0413348227739334, Training accuracy: 72.07392197125257%, Validation loss: 1.0690206289291382, Validation accuracy: 66.66666666666667%
# Epoch 1350/2000, Training loss: 1.036040723323822, Training accuracy: 72.68993839835728%, Validation loss: 1.062485158443451, Validation accuracy: 69.1358024691358%
# Epoch 1400/2000, Training loss: 1.0305657088756561, Training accuracy: 72.68993839835728%, Validation loss: 1.0637214183807373, Validation accuracy: 69.1358024691358%
# Epoch 1450/2000, Training loss: 1.0268660187721252, Training accuracy: 74.33264887063655%, Validation loss: 1.0606273412704468, Validation accuracy: 67.90123456790124%
# Epoch 1500/2000, Training loss: 1.0258385837078094, Training accuracy: 74.12731006160165%, Validation loss: 1.0601157546043396, Validation accuracy: 69.1358024691358%
# Epoch 1550/2000, Training loss: 1.0196747034788132, Training accuracy: 74.12731006160165%, Validation loss: 1.0582774877548218, Validation accuracy: 69.75308641975309%
# Epoch 1600/2000, Training loss: 1.0128017365932465, Training accuracy: 75.35934291581108%, Validation loss: 1.0599048733711243, Validation accuracy: 69.1358024691358%
# Epoch 1650/2000, Training loss: 1.011768564581871, Training accuracy: 76.38603696098562%, Validation loss: 1.0521693229675293, Validation accuracy: 70.37037037037037%
# Epoch 1700/2000, Training loss: 1.0076561570167542, Training accuracy: 74.94866529774127%, Validation loss: 1.0508183240890503, Validation accuracy: 69.75308641975309%
# Epoch 1750/2000, Training loss: 1.009420245885849, Training accuracy: 75.15400410677618%, Validation loss: 1.0525668263435364, Validation accuracy: 68.51851851851852%
# Epoch 1800/2000, Training loss: 1.0052744895219803, Training accuracy: 77.20739219712526%, Validation loss: 1.0540978908538818, Validation accuracy: 68.51851851851852%
# Epoch 1850/2000, Training loss: 0.9971203953027725, Training accuracy: 77.61806981519507%, Validation loss: 1.0485323667526245, Validation accuracy: 69.1358024691358%
# Epoch 1900/2000, Training loss: 0.996850311756134, Training accuracy: 78.43942505133471%, Validation loss: 1.0476434230804443, Validation accuracy: 69.1358024691358%
# Epoch 1950/2000, Training loss: 0.9944114536046982, Training accuracy: 76.18069815195072%, Validation loss: 1.0414214134216309, Validation accuracy: 69.75308641975309%
# Epoch 2000/2000, Training loss: 0.989387258887291, Training accuracy: 78.85010266940452%, Validation loss: 1.0432265996932983, Validation accuracy: 69.1358024691358%
# Validation accuracy (%) = 69.1358024691358
# For c = 1
# Epoch 1/2000, Training loss: 1.3861925601959229, Training accuracy: 24.024640657084188%, Validation loss: 1.3862741589546204, Validation accuracy: 23.45679012345679%
# Epoch 50/2000, Training loss: 1.3844542801380157, Training accuracy: 27.515400410677618%, Validation loss: 1.3877888321876526, Validation accuracy: 23.45679012345679%
# Epoch 100/2000, Training loss: 1.383989840745926, Training accuracy: 27.515400410677618%, Validation loss: 1.3873933553695679, Validation accuracy: 23.45679012345679%
# Epoch 150/2000, Training loss: 1.3828017115592957, Training accuracy: 27.515400410677618%, Validation loss: 1.3853831887245178, Validation accuracy: 23.45679012345679%
# Epoch 200/2000, Training loss: 1.3631051778793335, Training accuracy: 44.35318275154004%, Validation loss: 1.3674877882003784, Validation accuracy: 42.592592592592595%
# Epoch 250/2000, Training loss: 1.2889646887779236, Training accuracy: 43.94250513347023%, Validation loss: 1.3021361231803894, Validation accuracy: 41.358024691358025%
# Epoch 300/2000, Training loss: 1.2480674386024475, Training accuracy: 46.40657084188912%, Validation loss: 1.2603877186775208, Validation accuracy: 43.82716049382716%
# Epoch 350/2000, Training loss: 1.2263244092464447, Training accuracy: 49.281314168377826%, Validation loss: 1.2339584827423096, Validation accuracy: 45.06172839506173%
# Epoch 400/2000, Training loss: 1.2094824612140656, Training accuracy: 52.97741273100616%, Validation loss: 1.2113656401634216, Validation accuracy: 47.53086419753087%
# Epoch 450/2000, Training loss: 1.1952900290489197, Training accuracy: 51.540041067761805%, Validation loss: 1.198382556438446, Validation accuracy: 49.382716049382715%
# Epoch 500/2000, Training loss: 1.1844603717327118, Training accuracy: 53.79876796714579%, Validation loss: 1.1858370304107666, Validation accuracy: 53.7037037037037%
# Epoch 550/2000, Training loss: 1.1765164732933044, Training accuracy: 57.90554414784394%, Validation loss: 1.1727380752563477, Validation accuracy: 56.79012345679013%
# Epoch 600/2000, Training loss: 1.1678109765052795, Training accuracy: 57.49486652977413%, Validation loss: 1.163410246372223, Validation accuracy: 58.02469135802469%
# Epoch 650/2000, Training loss: 1.1634941101074219, Training accuracy: 58.93223819301848%, Validation loss: 1.1556360721588135, Validation accuracy: 57.407407407407405%
# Epoch 700/2000, Training loss: 1.1545958817005157, Training accuracy: 57.700205338809035%, Validation loss: 1.1436575651168823, Validation accuracy: 61.72839506172839%
# Epoch 750/2000, Training loss: 1.149482786655426, Training accuracy: 58.521560574948666%, Validation loss: 1.1393758654594421, Validation accuracy: 62.34567901234568%
# Epoch 800/2000, Training loss: 1.1465503573417664, Training accuracy: 62.012320328542096%, Validation loss: 1.1388084888458252, Validation accuracy: 59.876543209876544%
# Epoch 850/2000, Training loss: 1.137548178434372, Training accuracy: 59.75359342915811%, Validation loss: 1.1244207620620728, Validation accuracy: 62.34567901234568%
# Epoch 900/2000, Training loss: 1.1334076821804047, Training accuracy: 60.369609856262834%, Validation loss: 1.1239526867866516, Validation accuracy: 64.19753086419753%
# Epoch 950/2000, Training loss: 1.1298257112503052, Training accuracy: 60.57494866529774%, Validation loss: 1.1151846051216125, Validation accuracy: 64.81481481481481%
# Epoch 1000/2000, Training loss: 1.1334562301635742, Training accuracy: 58.72689938398357%, Validation loss: 1.1081686615943909, Validation accuracy: 64.81481481481481%
# Epoch 1050/2000, Training loss: 1.1220894753932953, Training accuracy: 62.012320328542096%, Validation loss: 1.1077606081962585, Validation accuracy: 62.34567901234568%
# Epoch 1100/2000, Training loss: 1.1197369992733002, Training accuracy: 61.80698151950719%, Validation loss: 1.100058913230896, Validation accuracy: 65.4320987654321%
# Epoch 1150/2000, Training loss: 1.11654794216156, Training accuracy: 61.190965092402465%, Validation loss: 1.095562756061554, Validation accuracy: 66.04938271604938%
# Epoch 1200/2000, Training loss: 1.115805596113205, Training accuracy: 62.83367556468173%, Validation loss: 1.1037442684173584, Validation accuracy: 61.72839506172839%
# Epoch 1250/2000, Training loss: 1.1170534491539001, Training accuracy: 63.860369609856264%, Validation loss: 1.092444121837616, Validation accuracy: 62.34567901234568%
# Epoch 1300/2000, Training loss: 1.1065897047519684, Training accuracy: 62.83367556468173%, Validation loss: 1.0860402584075928, Validation accuracy: 64.81481481481481%
# Epoch 1350/2000, Training loss: 1.1045930683612823, Training accuracy: 64.27104722792608%, Validation loss: 1.0935912132263184, Validation accuracy: 64.81481481481481%
# Epoch 1400/2000, Training loss: 1.0983280837535858, Training accuracy: 64.27104722792608%, Validation loss: 1.0816754698753357, Validation accuracy: 65.4320987654321%
# Epoch 1450/2000, Training loss: 1.0975238382816315, Training accuracy: 67.14579055441479%, Validation loss: 1.0781987309455872, Validation accuracy: 66.66666666666667%
# Epoch 1500/2000, Training loss: 1.0915050506591797, Training accuracy: 64.27104722792608%, Validation loss: 1.077543318271637, Validation accuracy: 64.81481481481481%
# Epoch 1550/2000, Training loss: 1.0888465642929077, Training accuracy: 67.35112936344969%, Validation loss: 1.0760741829872131, Validation accuracy: 67.28395061728395%
# Epoch 1600/2000, Training loss: 1.0893777906894684, Training accuracy: 65.70841889117042%, Validation loss: 1.0739704966545105, Validation accuracy: 66.66666666666667%
# Epoch 1650/2000, Training loss: 1.0846126675605774, Training accuracy: 66.52977412731006%, Validation loss: 1.0715062022209167, Validation accuracy: 66.66666666666667%
# Epoch 1700/2000, Training loss: 1.0886985659599304, Training accuracy: 66.52977412731006%, Validation loss: 1.0738559365272522, Validation accuracy: 63.58024691358025%
# Epoch 1750/2000, Training loss: 1.0839763283729553, Training accuracy: 67.14579055441479%, Validation loss: 1.0662546157836914, Validation accuracy: 67.28395061728395%
# Epoch 1800/2000, Training loss: 1.08259516954422, Training accuracy: 67.14579055441479%, Validation loss: 1.072490632534027, Validation accuracy: 64.81481481481481%
# Epoch 1850/2000, Training loss: 1.0750540792942047, Training accuracy: 65.09240246406571%, Validation loss: 1.0638983845710754, Validation accuracy: 67.90123456790124%
# Epoch 1900/2000, Training loss: 1.0702806413173676, Training accuracy: 67.96714579055441%, Validation loss: 1.0643985867500305, Validation accuracy: 68.51851851851852%
# Epoch 1950/2000, Training loss: 1.0708959102630615, Training accuracy: 68.78850102669405%, Validation loss: 1.061115026473999, Validation accuracy: 68.51851851851852%
# Epoch 2000/2000, Training loss: 1.0718428790569305, Training accuracy: 66.73511293634498%, Validation loss: 1.0614969730377197, Validation accuracy: 69.1358024691358%
# Validation accuracy (%) = 69.1358024691358

# %% [markdown]
# I find that the optimal value of $c$ is the lowest considered, *i.e.*, 0.01. This suggests that adding noise with a low standard deviation is enough for the data augmentation approach to improve model performance. As the noise level increases, the model continues to perform reasonably well, but accuracy declines. This is likely because higher noise levels obscure the relationship between the images and their respective classes, making classification more challenging.

# %%
noise_optimal = np.random.normal(0, np.sqrt(optimal_c) * np.std(star_images_train[class_3_indices], axis=0), star_images_train[class_3_indices].shape)
x_augmented_optimal = np.clip(star_images_train[class_3_indices] + noise_optimal, 0, 1)
y_augmented_optimal = np.full(len(x_augmented_optimal), 3)

x_train_da = np.concatenate((x_train_imbalanced, x_augmented_optimal), axis=0)
y_train_da = np.concatenate((y_train_imbalanced, y_augmented_optimal), axis=0)

x_train_da, y_train_da, x_val_da, y_val_da = dataset_split(x_train_da, y_train_da, val_size)
train_da_loader, val_da_loader = create_dataloaders(x_train_da, y_train_da, x_val_da, y_val_da, batch_size=128)

model_da, criterion_da, optimiser_da = get_model(x_train, n_filters, k, pool_size, stride_pool, classes)
history_da = training_loop(model_da, train_da_loader, val_da_loader, criterion_da, optimiser_da, max_num_epochs, max_patience)
plot_loss_accuracy(history_da)
# Out:
# Epoch 1/2000, Training loss: 1.3852925539016723, Training accuracy: 29.06764168190128%, Validation loss: 1.3811509609222412, Validation accuracy: 32.417582417582416%
# Epoch 50/2000, Training loss: 1.3641515254974366, Training accuracy: 33.45521023765996%, Validation loss: 1.380053460597992, Validation accuracy: 32.417582417582416%
# Epoch 100/2000, Training loss: 1.3729395866394043, Training accuracy: 33.45521023765996%, Validation loss: 1.378492295742035, Validation accuracy: 32.417582417582416%
# Epoch 150/2000, Training loss: 1.37204110622406, Training accuracy: 33.45521023765996%, Validation loss: 1.378914713859558, Validation accuracy: 32.417582417582416%
# Epoch 200/2000, Training loss: 1.3147154092788695, Training accuracy: 35.831809872029254%, Validation loss: 1.3280017375946045, Validation accuracy: 34.065934065934066%
# Epoch 250/2000, Training loss: 1.2229297637939454, Training accuracy: 48.62888482632541%, Validation loss: 1.224100649356842, Validation accuracy: 48.35164835164835%
# Epoch 300/2000, Training loss: 1.185562252998352, Training accuracy: 53.93053016453382%, Validation loss: 1.1918230056762695, Validation accuracy: 52.747252747252745%
# Epoch 350/2000, Training loss: 1.1507737398147584, Training accuracy: 56.48994515539305%, Validation loss: 1.1635136008262634, Validation accuracy: 53.2967032967033%
# Epoch 400/2000, Training loss: 1.1372652053833008, Training accuracy: 65.44789762340037%, Validation loss: 1.145117163658142, Validation accuracy: 62.08791208791209%
# Epoch 450/2000, Training loss: 1.1098401546478271, Training accuracy: 65.44789762340037%, Validation loss: 1.1341115832328796, Validation accuracy: 63.18681318681319%
# Epoch 500/2000, Training loss: 1.1011469125747682, Training accuracy: 66.54478976234003%, Validation loss: 1.112706184387207, Validation accuracy: 66.48351648351648%
# Epoch 550/2000, Training loss: 1.0940786361694337, Training accuracy: 67.09323583180988%, Validation loss: 1.10447758436203, Validation accuracy: 63.73626373626374%
# Epoch 600/2000, Training loss: 1.0870509147644043, Training accuracy: 66.17915904936015%, Validation loss: 1.0946630239486694, Validation accuracy: 68.68131868131869%
# Epoch 650/2000, Training loss: 1.0730300188064574, Training accuracy: 67.82449725776965%, Validation loss: 1.0855913758277893, Validation accuracy: 67.58241758241758%
# Epoch 700/2000, Training loss: 1.056592011451721, Training accuracy: 69.83546617915906%, Validation loss: 1.0775086879730225, Validation accuracy: 68.13186813186813%
# Epoch 750/2000, Training loss: 1.0552690505981446, Training accuracy: 71.11517367458866%, Validation loss: 1.071821689605713, Validation accuracy: 70.87912087912088%
# Epoch 800/2000, Training loss: 1.0563564777374268, Training accuracy: 69.6526508226691%, Validation loss: 1.061573326587677, Validation accuracy: 67.03296703296704%
# Epoch 850/2000, Training loss: 1.0449483871459961, Training accuracy: 70.56672760511883%, Validation loss: 1.0631204843521118, Validation accuracy: 69.78021978021978%
# Epoch 900/2000, Training loss: 1.041053295135498, Training accuracy: 70.56672760511883%, Validation loss: 1.0652283430099487, Validation accuracy: 68.68131868131869%
# Epoch 950/2000, Training loss: 1.043126153945923, Training accuracy: 72.21206581352834%, Validation loss: 1.058752715587616, Validation accuracy: 70.32967032967034%
# Epoch 1000/2000, Training loss: 1.0309760808944701, Training accuracy: 71.66361974405851%, Validation loss: 1.0607028603553772, Validation accuracy: 68.68131868131869%
# Epoch 1050/2000, Training loss: 1.0308557271957397, Training accuracy: 72.76051188299817%, Validation loss: 1.0445619225502014, Validation accuracy: 69.78021978021978%
# Epoch 1100/2000, Training loss: 1.0351077675819398, Training accuracy: 73.85740402193784%, Validation loss: 1.0461215376853943, Validation accuracy: 68.68131868131869%
# Epoch 1150/2000, Training loss: 1.0262409567832946, Training accuracy: 72.57769652650822%, Validation loss: 1.0378810167312622, Validation accuracy: 69.23076923076923%
# Epoch 1200/2000, Training loss: 1.018933081626892, Training accuracy: 73.12614259597807%, Validation loss: 1.0487664341926575, Validation accuracy: 71.42857142857143%
# Epoch 1250/2000, Training loss: 1.016125988960266, Training accuracy: 73.12614259597807%, Validation loss: 1.0462414622306824, Validation accuracy: 71.42857142857143%
# Epoch 1300/2000, Training loss: 1.0163192987442016, Training accuracy: 74.77148080438756%, Validation loss: 1.0402621030807495, Validation accuracy: 73.07692307692308%
# Epoch 1350/2000, Training loss: 1.0078975200653075, Training accuracy: 74.95429616087752%, Validation loss: 1.0372878909111023, Validation accuracy: 71.97802197802197%
# Epoch 1400/2000, Training loss: 1.0248287916183472, Training accuracy: 75.86837294332724%, Validation loss: 1.0359649062156677, Validation accuracy: 70.32967032967034%
# Epoch 1450/2000, Training loss: 1.0177810788154602, Training accuracy: 71.66361974405851%, Validation loss: 1.0438370108604431, Validation accuracy: 68.68131868131869%
# Epoch 1500/2000, Training loss: 1.0000882029533387, Training accuracy: 76.59963436928702%, Validation loss: 1.023864984512329, Validation accuracy: 72.52747252747253%
# Epoch 1550/2000, Training loss: 0.9983369588851929, Training accuracy: 76.78244972577697%, Validation loss: 1.0230939984321594, Validation accuracy: 73.62637362637362%
# Epoch 1600/2000, Training loss: 0.9946838617324829, Training accuracy: 76.23400365630712%, Validation loss: 1.0166444778442383, Validation accuracy: 73.07692307692308%
# Epoch 1650/2000, Training loss: 0.9823359727859498, Training accuracy: 76.96526508226691%, Validation loss: 1.0164859294891357, Validation accuracy: 71.97802197802197%
# Epoch 1700/2000, Training loss: 0.9996800184249878, Training accuracy: 75.86837294332724%, Validation loss: 1.017423152923584, Validation accuracy: 74.17582417582418%
# Epoch 1750/2000, Training loss: 0.983465313911438, Training accuracy: 77.14808043875685%, Validation loss: 1.0204721689224243, Validation accuracy: 71.97802197802197%
# Epoch 1800/2000, Training loss: 0.99421706199646, Training accuracy: 78.06215722120658%, Validation loss: 1.0200169682502747, Validation accuracy: 74.17582417582418%
# Epoch 1850/2000, Training loss: 0.9935725212097168, Training accuracy: 75.3199268738574%, Validation loss: 1.0243871808052063, Validation accuracy: 72.52747252747253%
# Epoch 1900/2000, Training loss: 0.9868094444274902, Training accuracy: 77.6965265082267%, Validation loss: 1.022076964378357, Validation accuracy: 72.52747252747253%
# Epoch 1950/2000, Training loss: 0.9707086443901062, Training accuracy: 78.79341864716636%, Validation loss: 1.0113043189048767, Validation accuracy: 73.62637362637362%
# Epoch 2000/2000, Training loss: 0.9823972225189209, Training accuracy: 79.3418647166362%, Validation loss: 1.0100111365318298, Validation accuracy: 73.62637362637362%

# %% [markdown]
# In this case, we observe that all loss and accuracy curves reach a *plateau*. Finally, we evaluate the accuracies of three models: the initial model trained on a depleted Class 3 dataset without any class imbalance mitigation, the model trained with a reweighted loss function, and the model trained using data augmentation with Gaussian noise.

# %%
accuracy_imbalanced = evaluate_model(model, x_test, y_test)
accuracy_weighted = evaluate_model(model_weighted, x_test, y_test)
accuracy_da = evaluate_model(model_da, x_test, y_test)

print('Test Accuracies:')
print(f'Imbalanced model: {accuracy_imbalanced:.2f}%')
print(f'Reweighted loss model: {accuracy_weighted:.2f}%')
print(f'Data augmentation model: {accuracy_da:.2f}%')
# Out:
# Test Accuracies:
# Imbalanced model: 25.00%
# Reweighted loss model: 25.00%
# Data augmentation model: 81.25%

# %% [markdown]
# Our results indicate that the best-performing model was the initial one, trained without regularisation and the original (balanced) dataset. While regularisation can help in overfitting scenarios, it did not provide a clear advantage here, though overall performance remained comparably high. When training on an imbalanced dataset without any mitigation strategies, accuracy dropped significantly, approaching a random guessing situation. Reweighting the loss to give more importance to the minority class proved insufficient to fully address the imbalance. However, augmenting the dataset by adding noise to duplicated samples of the depleted class led to a substantial improvement in accuracy, demonstrating the effectiveness of data augmentation in this context.

# %% [markdown]
#   <a name="task-13m"></a>
#
# ## (1.3, MSc/4th-year students only) [(index)](#index-task-13m)

# %% [markdown]
# I create the requested imbalanced training set by randomly dropping half of the data points in class 3 (M5V) from the original training set. I split the resulting dataset into 75% for actual training and 25% for validation.

# %%
np.random.seed(0)
class_3_indices = np.where(star_classes_train == 3)[0]
selected_indices = np.random.choice(class_3_indices, len(class_3_indices) // 2, replace=False)
remaining_indices = np.setdiff1d(np.arange(len(star_classes_train)), selected_indices)

x_train_imbalanced = star_images_train[remaining_indices]
y_train_imbalanced = star_classes_train[remaining_indices]

x_train, y_train, x_val, y_val = dataset_split(x_train_imbalanced, y_train_imbalanced, val_size)
train_loader, val_loader = create_dataloaders(x_train, y_train, x_val, y_val, batch_size=128)
model, criterion, optimiser = get_model(x_train, n_filters, k, pool_size, stride_pool, classes)
history_imbalanced = training_loop(model, train_loader, val_loader, criterion, optimiser, max_num_epochs, max_patience)
plot_loss_accuracy(history_imbalanced)
# Out:
# Epoch 1/2000, Training loss: 1.3859215378761292, Training accuracy: 30.046948356807512%, Validation loss: 1.3867107033729553, Validation accuracy: 29.577464788732396%
# Epoch 50/2000, Training loss: 1.3474411070346832, Training accuracy: 30.985915492957748%, Validation loss: 1.4110147953033447, Validation accuracy: 21.830985915492956%
# Epoch 100/2000, Training loss: 1.357706069946289, Training accuracy: 30.985915492957748%, Validation loss: 1.4128751754760742, Validation accuracy: 21.830985915492956%
# Epoch 150/2000, Training loss: 1.3552295863628387, Training accuracy: 30.046948356807512%, Validation loss: 1.41303288936615, Validation accuracy: 29.577464788732396%
# Early stopping acting.

# %% [markdown]
# Now the performance has drastically dropped. I modify the loss function by assigning the weight of each class to be the reciprocal of the class frequency.

# %%
weights = torch.tensor(1.0 / np.bincount(y_train), dtype=torch.float32)
criterion_weighted = CrossEntropyLoss(weight=weights)

model_weighted, criterion_weighted, optimiser_weighted = get_model(x_train, n_filters, k, pool_size, stride_pool, classes)
history_weighted = training_loop(model_weighted, train_loader, val_loader, criterion_weighted, optimiser_weighted, max_num_epochs, max_patience)
plot_loss_accuracy(history_weighted)
# Out:
# Epoch 1/2000, Training loss: 1.384799212217331, Training accuracy: 30.516431924882628%, Validation loss: 1.3875991702079773, Validation accuracy: 29.577464788732396%
# Epoch 50/2000, Training loss: 1.3561919927597046, Training accuracy: 30.516431924882628%, Validation loss: 1.4129433035850525, Validation accuracy: 29.577464788732396%
# Epoch 100/2000, Training loss: 1.3586541414260864, Training accuracy: 31.92488262910798%, Validation loss: 1.41041499376297, Validation accuracy: 29.577464788732396%
# Epoch 150/2000, Training loss: 1.3508824408054352, Training accuracy: 30.516431924882628%, Validation loss: 1.4142815470695496, Validation accuracy: 29.577464788732396%
# Early stopping acting.

# %% [markdown]
# Utilising a reweighted loss function does not seem to be enough to recover performance. As a second approach, I produce new training data of the minority class (Class 3) by using each image in the depleted class 3 to obtain one additional training image by rotating it, choosing uniformly at random a rotation of either 90, 180, or 270 degrees.

# %%
x_augmented = np.concatenate([np.rot90(x_train_imbalanced[y_train_imbalanced == 3], k=angle, axes=(1, 2)) for angle in [1, 2, 3]], axis=0)
y_augmented = np.full(len(x_augmented), 3)

x_train_da = np.concatenate((x_train_imbalanced, x_augmented), axis=0)
y_train_da = np.concatenate((y_train_imbalanced, y_augmented), axis=0)

x_train_da, y_train_da, x_val_da, y_val_da = dataset_split(x_train_da, y_train_da, val_size)
train_da_loader, val_da_loader = create_dataloaders(x_train_da, y_train_da, x_val_da, y_val_da)

model_da, criterion_da, optimiser_da = get_model(x_train, n_filters, k, pool_size, stride_pool, classes)
history_da = training_loop(model_da, train_loader, val_loader, criterion_da, optimiser_da, max_num_epochs, max_patience)
plot_loss_accuracy(history_da)
# Out:
# Epoch 1/2000, Training loss: 1.3863845765590668, Training accuracy: 26.995305164319248%, Validation loss: 1.386878252029419, Validation accuracy: 29.577464788732396%
# Epoch 50/2000, Training loss: 1.348781168460846, Training accuracy: 30.985915492957748%, Validation loss: 1.4106300473213196, Validation accuracy: 21.830985915492956%
# Epoch 100/2000, Training loss: 1.3510749340057373, Training accuracy: 28.4037558685446%, Validation loss: 1.4122640490531921, Validation accuracy: 21.830985915492956%
# Epoch 150/2000, Training loss: 1.3585185110569, Training accuracy: 30.985915492957748%, Validation loss: 1.411691665649414, Validation accuracy: 21.830985915492956%
# Early stopping acting.

# %% [markdown]
#  While CNNs are designed to be invariant to transformations like rotations, the considered augmentation approach does not add meaningful diversity to the dataset. Instead of introducing new features, it provides more of the same information in a different orientation, which does not help the model learn better class representations.

# %%
accuracy_imbalanced = evaluate_model(model, x_test, y_test)
accuracy_weighted = evaluate_model(model_weighted, x_test, y_test)
accuracy_da = evaluate_model(model_da, x_test, y_test)

print('Test Accuracies:')
print(f'Imbalanced model: {accuracy_imbalanced:.2f}%')
print(f'Reweighted loss model: {accuracy_weighted:.2f}%')
print(f'Data augmentation model: {accuracy_da:.2f}%')
# Out:
# Test Accuracies:
# Imbalanced model: 25.00%
# Reweighted loss model: 25.00%
# Data augmentation model: 25.00%

# %% [markdown]
# Our results indicate that the best-performing model was the initial one, trained without regularisation and the original (balanced) dataset. While regularisation can help in overfitting scenarios, it did not provide a clear advantage here, though overall performance remained comparably high. When training on an imbalanced dataset without any mitigation strategies, accuracy dropped significantly, approaching a random guessing situation. Neither reweighting the loss to emphasise the minority class nor augmenting the dataset with rotated images was sufficient to effectively mitigate the class imbalance.

# %% [markdown]
# ---

# %% [markdown]
# <a name="task-2"></a>
#
# # (2) Task 2: Dimensionality Reduction: PCA vs ISOMAP [(index)](#index-task-2)

# %% [markdown]
# I import `star_embeddings_train` $648$ $180$-dimensional embeddings of the star images in the training set, one for each star. I will perform dimensionality reduction of these embeddings. As illustration, I plot the first ttwo dimensions using the star class as colour.

# %%
X = np.load(PATH + 'star_embeddings_train.npy')
classes = [0, 1, 2, 3]

# %%
fig, ax = plt.subplots(figsize=(8,8))
scatter = plt.scatter(X[:,0], X[:,1], c=star_classes_train)
legend = plt.legend(handles=scatter.legend_elements()[0], labels=[value_to_type[c] for c in classes])

for handle, label in zip(legend.legend_handles, star_classes_train):
    handle.set_label(label)
plt.xlabel(u'$X_1$')
plt.ylabel(u'$X_2$')
plt.show()

# %% [markdown]
# <a name="task-21"></a>
#
# ## (2.1) [(index)](#index-task-21)

# %% [markdown]
# I first standardise the data (obtaining `X_std`) for use in PCA.

# %%
def standardise(X):
    """
    Arguments:
    X: Data with samples being indexed along axis 0.

    Returns:
    Xbar: Standardised data.

    """
    mu = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    std[std==0] = 1.
    Xbar = (X - mu) / std

    return Xbar

# %%
X_std = standardise(X)

# %% [markdown]
# Now I perform PCA - a dimensionality reduction technique consisting of projecting the data on the directions of maximal variance.
#
# To this end, I compute the data covariance matrix `C` and then I diagonalise it to find its `m` largest eigevalues and corresponding eigenvectors - the principal components. The coordinates of the data projected onto the first `m` principal components are stored in the matrix `X_PCA`; here I take `m= 2`.
#
# First, I import the functions to perform PCA from the coding tasks.

# %%
def covariance_matrix(X):
    """
    Arguments:
    X: Data with samples being indexed along axis 0.

    Returns:
    Xbar: Computes the data covariance matrix.

    """
    return np.dot(X.T, X) / len(X)

def pca_function(X, k):
    """
    Arguments:
    X: Data with samples being indexed along axis 0.
    k: Number of principal components.

    Returns:
    X_pca: Transformed data.
    eigenvectors: First k eigenvectors of C.
    eigenvalues: First k eigenvalues of C.

    """
    # Computing the covariance matrix
    C = covariance_matrix(X)

    # Computing the eigenvalues and eigenvectors using the eigsh scipy function
    eigen = linalg.eigh(C)

    # extract the k principle components and eigenvalues
    eigenvalues = eigen.eigenvalues[::-1][0:k]
    eigenvectors = eigen.eigenvectors[:, ::-1][:, 0:k]

    # Projecting the data onto the directions of eigenvectors
    X_pca = X.dot(eigenvectors)

    return X_pca, eigenvectors, eigenvalues

# %%
# Compute first two principal components
X_pca, _, _ = pca_function(X_std, 2)

# plot
fig, ax = plt.subplots(figsize=(8,8))
scatter = plt.scatter(X_pca[:,0], X_pca[:,1], c=star_classes_train)
legend = plt.legend(handles=scatter.legend_elements()[0], labels=[value_to_type[c] for c in classes])

for handle, label in zip(legend.legend_handles, star_classes_train):
    handle.set_label(label)
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title(f'PCA on star image embeddings')
plt.show()

# %% [markdown]
# From the plot of the projection of the star embeddings onto the space of the first two principal components, one observes that data points from class M5V tend to cluster away from the other classes (O5V, A0V, F5V).
#
# This suggests that there are some similarities between data in these latter classes, and conversely that the discriminative features between classes are not fully captured by the first two principal components. Hence, the PCA lower-dimensional representation might not be very effective at facilitating classification, especially in connection to these 3 classes. A non-linear dimensionality reduction method might be needed to obtain a dimensionality reduction that is more effective in this regard.
#
# To quantitate how well the PCA representation reflects the separation into classes, I next compute the Davies-Bouldin (DB) Index.

# %% [markdown]
# I define a function `davies_bouldin_index` to calculate the DB Index. Its steps are as follows:
#
# 1. Given the data and their cluster labels, compute the centroids of each cluster like in $K$-means, i.e., each coordinate of the centroid is the average coordinate across points in that cluster.
#
# 2. For each cluster $\alpha$, compute $S_{\alpha}$ as the the average Euclidean distance between each point of cluster and the centroid of that cluster.
#
# 3. For each pair of clusters $\alpha$ and $\beta$, compute $M_{\alpha \beta}$ as the Euclidean distance between the centroids of clusters.
#
# 4. Compute $F_{\alpha \beta} = \frac{S_{\alpha} + S_{\beta}}{M_{\alpha\beta}}$, which summarises the trade-off of within-cluster cohesion and the between-clusters separation, for two clusters $\alpha$ and $\beta$.
#
# 5. Compute `davies_bouldin_index` as $\frac{1}{C} \sum_{\alpha=1}^C \text{max}_{\beta, \beta \neq \alpha} F_{\alpha \beta}$, i.e., as an average over clusters of the maximum of $F_{\alpha \beta}$ across clusters' pairwise comparisons.

# %%
def davies_bouldin_index(X, labels):
    """Compute the Davies-Bouldin index (DBI) for a given clustering given the data and the labels.

     Args:
        X (np.ndarray): the samples array, shape: (N, p).
        labels (np.ndarray): the labels array, shape: (N,).

    Returns:
        float: the DB Index.
    """

    # Compute the centroids of the clusters, given the data and their labels
    labels_unique = np.unique(labels)
    centroids = np.array([np.mean(X[labels == i], axis=0) for i in labels_unique])

    # Compute S_alpha for each cluster alpha
    S = np.array([np.mean(np.linalg.norm(X[labels == i] - centroids[i], axis=1)) for i in labels_unique])

    # Compute M_alpha,beta
    M = np.array([[np.linalg.norm(centroids[i] - centroids[j]) for j in labels_unique] for i in labels_unique])

    # Compute F_alpha
    F = np.zeros_like(M)
    for i in range(len(labels_unique)):
        for j in range(i+1, len(labels_unique)):
            F[i, j] = F[j, i] = (S[i] + S[j]) / M[i, j]

    # compute the DB index
    DB_index = np.mean([np.max(F[i][np.arange(len(centroids)) != i]) for i in range(len(centroids))])
    return DB_index

# %%
db_pca = davies_bouldin_index(X_pca, star_classes_train)
print(f'Davies bouldin index for the PCA dimensionality reduction of star image embeddings: {db_pca:.2f}')
# Out:
# Davies bouldin index for the PCA dimensionality reduction of star image embeddings: 2.85

# %% [markdown]
# The DB index gives an average of the maximal ratios of within-cluster distance and inter-cluster distance. Since in clustering the within-cluster distance should be minimised and the inter-cluster distance should be maximised, then the DB index gives in average the worst clustering performance across pairs of clusters. Hence, low values of the DB index is indication of compact,  well-separated clusters, hence of good clustering performance.
#
# A DB index of `2.85` suggests that the clustering performance is not high, indicating in this case that the PCA representation does not reflect very well the separation into classes. It essentially indicates high intra-cluster distance, evident already by visual inspection. This is probably because PCA projects the data onto the directions of maximal variance in the data, which would give rise to a good clustering by class if the separation between classes occurs in these directions, i.e., if points from different classes tend to differ in this projection. But here, as undelined above, points from the 3 classes O5V, A0V, F5V have a similar projection on both PCs (only the projection onto PC1 has some difference between these classes), and this is picked up in a value of the DB index typical of moderate clustering performance.

# %% [markdown]
# <a name="task-22"></a>
#
# ## (2.2) [(index)](#index-task-22)

# %% [markdown]
# Here I implement another dimensionality reduction algorithm based on a variant of ISOMAP, which is a dimensionality reduction technique based on graph learning.
#
# The first step is the graph construction, whose steps are as follows.
# 1. Compute the matrix of cosine distances between each pair of samples (here, the star embeddings), where the pairwise cosine distance $D_{ij}$ between $X_i$ and $X_j$ is given by:
#
# $$
# D_{ij} = 1 - \frac{X_i \cdot X_j}{||X_i||_2||X_j||_2}
# $$
#
# 2. Construct the adjacency matrix via the $k$-Nearest Neighbour ($k$NN) graph construction method with $k=9$, where two samples $X_i$ and $X_j$ are connected with an undirected edge of weight $D_{ij}$ if $X_i$ is within the $k$-nearest neighbours of $X_j$ and viceversa. I write the function `compute_kNN` for this step.

# %%
# Computation of the cosine distances

# number of features
p = X.shape[1]

# initialise the matrix of distances
D_cos = np.zeros((N,N))
for i in range(N):
    for j in range(i+1,N):
        D_cos[i,j] = 1 - (X[i].T @ X[j]) / (np.linalg.norm(X[i]) * np.linalg.norm(X[j]))
        D_cos[j,i] = D_cos[i,j] # it's clearly a symmetric matrix

# %%
def compute_kNN(D, k=9):
    """Compute kNN graph from distance matrix D.
     Args:
        D (np.ndarray): the distance matrix, shape: (N, N).
        k (int): the number of nearest neighbours.
    Returns:
        np.ndarray: the graph adjacency matrix A, shape: (N, N).
    """

    N = D.shape[0]

    # get k nearest neighbours for each point
    k_neighbours = np.argsort(D, axis=1)[:,1:k+1]

    # initialise adjacency matrix
    A = np.zeros((N,N))

    # build kNN graph
    for i in range(N):
        for neighbour in k_neighbours[i]:
            A[i,neighbour] = D[i,neighbour]
            A[neighbour,i] = A[i,neighbour]

    return A

# %%
# compute the kNN graph adjacency matrix A, for k=9
A = compute_kNN(D_cos, k=9)

# %%
# let's print some descriptive statistics to make sure the construction is as wanted and count the number of edges

print('Graph is undirected:', np.array_equal(A,A.T))
print('Graph is unweighted:', np.array_equal(np.unique(A),np.arange(2)))
print('Number of nodes:', A.shape[0])
print('Number of edges:', np.sum(A>0))
# Out:
# Graph is undirected: True
# Graph is unweighted: False
# Number of nodes: 648
# Number of edges: 7408

# %% [markdown]
# Now I visualise the resulting graph using the second (i.e., the Fiedler) and third eigenvectors of the symmetric Laplacian.

# %%
# compute degrees
d = A.sum(axis=0)
# define diagonal degree matrix
D = np.diag(d)

# compute combinatorial Laplacian
L = D - A

# compute square root of inverse diagonal degree matrix
D_sqrt_inv = np.diag(1/np.sqrt(d))

# compute symmetric normalised Laplacian
L_s = D_sqrt_inv @ L @ D_sqrt_inv

# compute eigen decomposition using the fact that
eigenvals, eigenvecs = np.linalg.eigh(L_s)

# sort eigenvalues and corresponding eigenvector
eigenvecs = eigenvecs.T[np.argsort(eigenvals)]
eigenvals = np.sort(eigenvals)

# get second (Fiedler) and third eigenvectors
v2 = eigenvecs[1]
v3 = eigenvecs[2]

# normalise coordinates
x_coord = D_sqrt_inv @ v2
y_coord = D_sqrt_inv @ v3

# plot
fig,ax=plt.subplots(figsize=(8,8))

# plot edges
for i in tqdm(range(N)):
    for j in range(i+1,N):
        if A[i,j] > 0:
            ax.plot([x_coord[i],x_coord[j]],[y_coord[i],y_coord[j]], color="black", alpha=0.5, linewidth=0.3)

# plot nodes
scatter = ax.scatter(x_coord,y_coord,s=4, c=star_classes_train, zorder=10)


# create legend for node types
legend = plt.legend(handles=scatter.legend_elements()[0], labels=[value_to_type[c] for c in classes])

# set labels
ax.set(xlabel='Normalised Fiedler eigenvector', ylabel='Normalised third eigenvector',
    title=f'kNN-graph with k=9')
plt.show()
print(f'Algebraic connectivity (eigenvalue associated to the Fiedler eigenvector): {eigenvals[1]:.2f}')
# Out:
#   0%|          | 0/648 [00:00<?, ?it/s]
# Algebraic connectivity (eigenvalue associated to the Fiedler eigenvector): 0.01

# %% [markdown]
# Also this spectral layout shows a clear separation of class $M5V$ (for which the components of the normalised Fiedler eigenvector are negative) from the other classes (signalled by positive Fiedler eigenvector components). Indeed, if we used the Fiedler eigenvector to bipartition the graph, we would obtain one partition with the class $M5V$, and one partition with the other classes.
#
# The algebraic connectivity (the eigenvalue associated with the Fiedler eigenvector) is very small, indicating that the two partitions are weakly connected on the graph, confirming that class $M5V$ well clusters aprt from the other samples.

# %% [markdown]
# <a name="task-22"></a>
#
# ## (2.3) [(index)](#index-task-23)

# %% [markdown]
# The next step of the Isomap-like algorithm is to compute the resistance distance $R_{ij}$ between graph nodes $i$ and $j$, which is defined as:
#
# $$
# R_{ij} = \Gamma_{ii} + \Gamma_{jj} - 2\Gamma_{ij}
# $$
# where $\Gamma = (L - \frac{1}{N}\mathbf{1}\mathbf{1}^T)^+$, $+$ denotes the Moore–Penrose inverse and $L$ combinatorial graph Laplacian that I computed above.
#
# For this, I use `np.linalg.pinv` to compute the pseudo-inverse.

# %%
# compute gamma matrix
G = np.linalg.pinv(L-1/N*np.ones((N,N)), hermitian=True)

# compute resistance distance
D_res = np.zeros((N,N))

for i in range(N):
    for j in range(i,N):
        D_res[i,j] = G[i,i] + G[j,j] - 2 * G[i,j]
        D_res[j,i] = D_res[i,j]

# %% [markdown]
# I now compare the mean resistance distance per node (obtained by averaging over all distances to other nodes) and the mean cosine distance, drawing a scatter plot.

# %%
# plot
fig, ax = plt.subplots(figsize=(8,8))

# plot nodes
scatter = ax.scatter(np.mean(D_cos,axis=0),np.mean(D_res,axis=0),alpha=0.5)

# set labels
ax.set(xlabel='Mean cosine distance', ylabel='Mean resistance distance',
    title=f'Comparison between cosine and resistance distance')
plt.show()

# %% [markdown]
# The mean cosine distance values are concentrated in a narrow range (roughly below 0.16) compared to the mean resistance distance (which goes up to roughly 600). Indeed, the cosine distance i defined as $1-cos(\theta)$, where $\theta$ is the angle between two data vectors, its value is bounded at 1. Values closer to zero than to 1 indicate an overall similarity between data vectors (i.e., they tend to be parallel rather than orthogonal).
#
# Resistance distance varies on a different scale, the scale of the size of the graph, as is defined in terms of the number and length of paths between two nodes in a graph.
#
# Next I compute the matrix $\tau$ from the resistance distance matrix $R$:
# $$
# \tau = -\frac{HSH}{2} \quad \text{with} \quad H = I - \frac{1}{N}\mathbf{1}\mathbf{1}^T \quad \text{and} \quad S_{ij} = R_{ij}^2
# $$
# and take the first two eigenvectors of $\tau$ as the final embedding to visualise the result of Isomap.

# %%
# define centering matrix
H = np.diag(np.ones(N)) - 1/N * np.ones((N,N))

# compute operator tau
tau = -H @ D_res**2 @ H/2

# %%
# compute eigen-decomposition of tau
eigenvals_tau, eigenvecs_tau = np.linalg.eigh(tau)

# sort eigenvalues and corresponding eigenvector in decreasing order
eigenvecs_tau = eigenvecs_tau.T[np.argsort(-eigenvals_tau)]
eigenvals_tau = -np.sort(-eigenvals_tau)

# define 2D isomap embedding taking the two first eigenvectors
X_iso = eigenvecs_tau[:2].T

# %%
fig, ax = plt.subplots(figsize=(8,8))
scatter = plt.scatter(X_iso[:,0], X_iso[:,1], c=star_classes_train)
legend = plt.legend(handles=scatter.legend_elements()[0], labels=[value_to_type[c] for c in classes])

for handle, label in zip(legend.legend_handles, star_classes_train):
    handle.set_label(label)
plt.xlabel('Isomap 1')
plt.ylabel('Isomap 2')
plt.title(f'Isomap with kNN (k={9}) and resistance distance')
plt.show()

# %% [markdown]
# The Isomap-like data dimensionality reduction, that I visualised in the $2D$ -space of the top two eigenvectors of the centred resistance distance matrix $\tau$, yields a much better-defined clustering of the $4$ star image classes.
# Not only class $M5V$ clusters apart, as it was clear already with PCA and graph spectral partitioning, but also the other 3 classes are now more separated mong them.
#
# I now compute the DB index.

# %% [markdown]
#  Evaluate how well this 2D representation matches the division into classes by calculating the  index, as in Task 2.1, and compare it to the results obtained from the 2D representation from PCA in Task 2.1. Discuss and explain the observed differences.

# %%
db_isomap = davies_bouldin_index(X_iso, star_classes_train)
print(f'Davies bouldin index for the Isomap-like dimensionality reduction of star image embeddings: {db_isomap:.2f}')
# Out:
# Davies bouldin index for the Isomap-like dimensionality reduction of star image embeddings: 1.94

# %%
db_table = pd.DataFrame({'Dimensionality reduction technique': ['PCA', 'Isomap-like'], 'DB Index': [db_pca, db_isomap]})
print(db_table.to_string(index=False))
# Out:
# Dimensionality reduction technique  DB Index
#                                PCA  2.853370
#                        Isomap-like  1.939467

# %% [markdown]
# As already clear from visual inspection, the Isomap-like lower-dimensional representation has better performance, in terms of clustering data consistently with their class, as quantified by the DB index: the DB index of the Isomap-like technique is lower than the one of PCA (with $1.94$ vs $2.85$).
#
# The PCA lower-dimensional representation, indeed, tended to have larger within-cluster distances and lower between-cluster distances, especially for the 3 hard-to-classify classes O5V, A0V, F5V.
#
#
# Presumably, the Isomap-like method performs better than PCA because it's a non-linear dimensionality reduction method (while PCA is linear), i.e., to obtain a representation separating the classes O5V, A0V, F5V one needs to capture non-linear relationships between data features and have a notion of distance between data points that takes them into account. The graph construction and the use of a distance metric defined on a graph are better suited for this task, because a graph is a way of obtaining a discrete approximation of the underlying manifold of the data. Then, the embedding chosen preserves distances on this graph, helping capture and visualise the relationships induced by the data manifold.
